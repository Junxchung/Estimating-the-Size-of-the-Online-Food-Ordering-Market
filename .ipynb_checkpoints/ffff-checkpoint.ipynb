# %% [markdown]
# # Cloud Kitchens / Otter | Take Home Assessment - Jun Chung

# %% [markdown]
# <img src="cloudkitchens.png">

# %% [markdown]
# ## Table of Contents
#
# [The Problem](#cell1) | [Importing the Data](#cell2) | [Cleaning the Data](#cell3) | [The Solution: Creating My Target Column](#cell4) | [Discussion: Potential Next Steps](#cell5)

# %% [markdown]
# <a id="cell1"></a>

# %% [markdown]
# ## The Problem
#
# #### Restaurants
# In order to estimate the market size of online food delivery, it is important to know how many restaurants offer online delivery services. This would be a simple aggregation if all restaurants registered their information on online food ordering (OFO) platforms the same way. But they don’t. Differences exist and an algorithm is needed to figure out if two restaurants on different platforms are actually the same restaurant or not.
#
# Note that the same restaurant could appear on different delivery platforms with slight restaurant name differences, and slight restaurant location differences.
#
# #### The Prompt
# You can download restaurant data for the US from [here](https://drive.google.com/file/d/16oyMbp9mtfGF88e_MFWrztZF-Fu3vyra/view?usp=sharing). Note the use of ​ctrl-a​ as a delimiter in the csv file.
#
# Design and implement an algorithm for finding all restaurant duplicates in the example dataset. Discuss how you would share the results with a business stakeholder.

# %% [markdown]
# <a id="cell2"></a>

# %% [markdown]
# ## Importing the Data
#
# Back to [Top](#cell1)
#
# Before anything else, I have to import the data set.

# %%
import pandas as pd

# %%
original_dataset = pd.read_csv('css_public_all_ofos_locations.csv', 
                   sep = chr(1), 
                   low_memory = False)

# %%
original_dataset.head(3)
# Out:
#   restaurant_id                name platform sub_platform   latitude  \
# 0          9744           Loco Coco   caviar          NaN  40.765004
# 1          4903              Musubi   caviar          NaN  45.504641
# 2          4723  The Bakers' Lounge   caviar          NaN  38.924559
#
#      longitude city country active  standardized_name restaurant_chain  \
# 0   -73.965961  NaN      US   TRUE          loco_coco              NaN
# 1  -122.643806  NaN      US  FALSE             musubi              NaN
# 2   -76.990115  NaN      US  FALSE  the_bakers_lounge              NaN
#
#   delivery_radius  geom
# 0             NaN   NaN
# 1             NaN   NaN
# 2             NaN   NaN

# %%
original_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 644089 entries, 0 to 644088
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   restaurant_id      644089 non-null  object
#  1   name               644086 non-null  object
#  2   platform           644087 non-null  object
#  3   sub_platform       599311 non-null  object
#  4   latitude           644086 non-null  object
#  5   longitude          644070 non-null  object
#  6   city               56196 non-null   object
#  7   country            644071 non-null  object
#  8   active             643867 non-null  object
#  9   standardized_name  643872 non-null  object
#  10  restaurant_chain   169 non-null     object
#  11  delivery_radius    354661 non-null  object
#  12  geom               0 non-null       float64
# dtypes: float64(1), object(12)
# memory usage: 63.9+ MB

# %%
print('The provided data has {0} rows and {1} columns of restaurant data.'.format(
    original_dataset.shape[0], 
    original_dataset.shape[1])
     )
# Out:
# The provided data has 644089 rows and 13 columns of restaurant data.

# %% [markdown]
# <a id="cell3"></a>

# %% [markdown]
# ## Cleaning the Data
#
# Back to [Top](#cell1)
#
# This step is very long with many substeps. Feel free to scroll all the way to the [Solution](#cell4) or [Discussion](#cell5) at the bottom of the notebook file.

# %% [markdown]
# #### Creating a New Dataset

# %%
# to keep the original provided dataset unaltered
# I am making a copy of the data to use for data cleaning, pre-processing, etc

data = original_dataset.copy()

# %% [markdown]
# I want to check to see if I can manually insert the missing names of the 3 rows missing values in the 'name' column.

# %%
# using simple boolean indexing to examine the rows with missing values for the 'name' column

print(data[data['name'].isnull()])
# Out:
#                     restaurant_id name      platform sub_platform latitude  \
# 34794                        None  NaN  delivery.com          NaN      NaN
# 236516  Recreation & Wellness Ctr  NaN           NaN          NaN      NaN
# 316021                  Suite 112  NaN           NaN          NaN      NaN
#
#        longitude city country active standardized_name restaurant_chain  \
# 34794        NaN  NaN      US  FALSE               NaN              NaN
# 236516       NaN  NaN     NaN    NaN               NaN              NaN
# 316021       NaN  NaN     NaN    NaN               NaN              NaN
#
#        delivery_radius  geom
# 34794              NaN   NaN
# 236516             NaN   NaN
# 316021             NaN   NaN

# %% [markdown]
# #### Deleting Rows with Little to No Value
#
# Because there is almost no other data I can use, such as latitude and longitude data, to determine what these restaurants may be, I am deleting these rows of data entirely from the dataset.

# %%
data.dropna(subset = ['name'], inplace = True)
data.reset_index(inplace = True, drop = True)

# %%
print('The dataset now has {0} rows and {1} columns of restaurant data.'.format(
    data.shape[0], 
    data.shape[1])
     )
# Out:
# The dataset now has 644086 rows and 13 columns of restaurant data.

# %% [markdown]
# #### Quick Data Transformations on Restaurant Names
#
# In order to prevent issues with analyses in the future, I will clean up restaurant name data using some string methods to:
# - Make every character lowercase
# - Replace all dashes ("-") and underscores ("_") with spaces
# - Removing all apostophes ("'")

# %%
data['name'] = data['name'].str.lower().str.replace('-', ' ').str.replace('_', ' ').str.replace('\'', '')

# %% [markdown]
# #### Removing Columns
#
# Some columns do not offer me much value and can be removed entirely from the data set.
# - 'city': obsolete as I have latitude and longitude coordinate data
# - 'restaurant_chain': too many missing values, although this column may be useful for ML models
# - 'delivery_radius': too many missing values
# - 'geom': no provided description of what this column should represent and filled entirely with NaN values
# - 'standardized_name': may be useful in the future but will use the 'name' column instead for the time being

# %%
data.drop(columns = ['city', 'restaurant_chain', 'delivery_radius', 'geom', 'standardized_name'], inplace = True)

data.columns
# Out:
# Index(['restaurant_id', 'name', 'platform', 'sub_platform', 'latitude',
#        'longitude', 'country', 'active'],
#       dtype='object')

# %% [markdown]
# #### Exploring Missing Latitude and Longitude Values
#
# My intention is to use the latitude and longitude values either as features in machine learning algorithms or to filter out duplicates simply. These two columns are very important to my goals and must be done carefully and thoroughly.

# %%
# checking what missing values may exist in the latitude column
# using simple boolean indexing to examine the rows with missing values for the 'latitude' column

print(data[data['latitude'].isnull()])
# Out:
# Empty DataFrame
# Columns: [restaurant_id, name, platform, sub_platform, latitude, longitude, country, active]
# Index: []

# %% [markdown]
# It appears that getting rid of the rows where the value in the 'name' column was missing also removed the rows that were missing latitude data.

# %%
# using the same method as above to examine the rows with missing values for the 'longitude' column

print('Only a few of the rows are displayed for easier viewing.\n')
print('--------------------------------------------------------\n')
print(data[data['longitude'].isnull()][:5])    # remove the indexing to see all rows with missing 'longitude' values
# Out:
# Only a few of the rows are displayed for easier viewing.
#
# --------------------------------------------------------
#
#                                             restaurant_id name  \
# 139275                                    20 Hugus Alley"  usd
# 187182                                           Ste 190"  usd
# 194074                                           Ste 170"  usd
# 201826  (b/t N P St & N Rhode Island Ave) in Logan Cir...  usd
# 204009                                           Ste 100"  usd
#
#                                                  platform sub_platform  \
# 139275  [["open: 12:00, close: 18:00"], ["open: 12:00,...         TRUE
# 187182                       [[], [], [], [], [], [], []]        FALSE
# 194074  [["open: 12:00, close: 21:00"], ["open: 12:00,...         TRUE
# 201826  [["open: 12:00, close: 21:30"], ["open: 12:00,...         TRUE
# 204009  [["open: 12:00, close: 18:30"], ["open: 12:00,...         TRUE
#
#                              latitude longitude country active
# 139275                      sugarfina       NaN     NaN     45
# 187182             ohjah_noodle_house       NaN     NaN     40
# 194074             novecento_pizzeria       NaN     NaN     50
# 201826  14th_street_cafe_asian_bistro       NaN     NaN     40
# 204009  straight_from_philly_steakout       NaN     NaN     45

# %% [markdown]
# It appears that, for whatever reason, data was not input and/or collected properly for the data points above. The values within each column seem to be in the wrong place. However, I can simply:
# - Look these restaurants up on the internet
# - Fill in + replace the existing values with correct values
#
# ##### Correct Information for Restaurants
# I'll be looking up the restaurants up by their names, which I am presuming are the values found in the 'latitude' column. I can confirm I am collecting information for the correct restaurants with the other information available (but misplaced) in the other columns.
# - Row 139275 (Sugarfina) [info](https://www.yelp.com/biz/sugarfina-pasadena-pasadena-2)
# - Row 187182 (Ohjah Nooodle House) [info](https://www.yelp.com/biz/ohjah-noodle-house-las-vegas-3)
# - Row 194074 (Novecento Pizzeria) [info](https://www.yelp.com/biz/novecento-pizzeria-las-vegas)
# - Row 201826 (14th St Cafe Asian Bistro) [info](https://www.yelp.com/biz/14th-st-cafe-asian-bistro-washington-2)
# - Row 204009 (Straight From Philly Steakout) [info](https://www.yelp.com/biz/straight-from-philly-steakout-henderson-3)
# - Row 229923 (Tumbao Buns - Downtown Miami) [info](https://www.yelp.com/biz/tumbao-buns-downtown-miami-miami-2)
#     - The address found on the Yelp page doesn't match with the one provided on the data set. This is most likely due to the fact that this restaurant is technically a food truck, a mobile restuarant that can have different locations. The correct address is listed [here](https://postmates.com/merchant/tumbao-buns-miami)
# - Row 250285 (Dunkin Donuts) [info](https://www.yelp.com/biz/dunkin-donuts-pompano-beach-7?osq=dunkin+donuts+locations)
# - Row 294759 (Dos Coyotes Border Cafe) [info](https://www.grubhub.com/restaurant/dos-coyotes-border-cafe-8519-bond-rd-ste-100-elk-grove/1244011)
# - Row 298938 (China One) [info](https://www.grubhub.com/restaurant/china-one-7080-n-durango-dr-ste-130-las-vegas/394082)
# - Row 302088 (Fat Boy) [info](https://www.yelp.com/biz/fat-boy-henderson-2)
# - Row 341276 (Au Bon Pain) [info](https://www.yelp.com/biz/au-bon-pain-chicago-14)
# - Row 344993 (Ohjah Noodle House 2) [info](https://www.grubhub.com/restaurant/ohjah-noodle-house-35-e-horizon-ridge-pkwy-ste-160-henderson/1121695)
#     - This may, interestingly, be the same as the other Ohjah Noodle House listed above. Investigate further.
# - Row 355632 (Cinnabon) [info](https://www.zomato.com/maricopa-county-az/scholtzskys-cinnabon-1-goodyear)
# - Row 379700 (Thailicious Authentic Thai & Vegan) [info](https://www.yelp.com/biz/thailicious-authentic-thai-and-vegan-henderson?osq=thailicious)
# - Row 391644 (Boss's Slow Smoked BBQ) [info](https://www.yelp.com/biz/bosss-slow-smoked-bbq-n-las-vegas)
# - Row 415759 (Buon Gusto Ristorante) [info](https://www.yelp.com/biz/buon-gusto-ristorante-henderson)

# %% [markdown]
# A closer look at our actual data set shows that the rows of data above are not unique data points but instead are repeats of rows directly preceding them.

# %%
print(data.iloc[250284:250286,:])
# Out:
#                                restaurant_id           name  \
# 250284  70f366b3-a6fd-4634-8e57-7364e8f23cd2  dunkin donuts
# 250285                          Fl Turnpike"            usd
#
#                             platform sub_platform       latitude  \
# 250284                     postmates   restaurant    28.51478909
# 250285  [[], [], [], [], [], [], []]        FALSE  dunkin_donuts
#
#            longitude country active
# 250284  -81.49956571      US    NaN
# 250285           NaN     NaN     40

# %%
indices_missing_lat = [139275, 187182, 194074, 
                    201826, 204009, 229923, 
                    250285, 294759, 298938, 
                    302088, 341276, 344993, 
                    355632, 379700, 391644, 415759]

for index in indices_missing_lat:
    print(data.iloc[index - 1,1])
# Out:
# sugarfina
# ohjah noodle house
# novecento pizzeria
# 14th street cafe asian bistro
# straight from philly steakout
# tumbao buns
# dunkin donuts
# dos coyotes border cafe
# china one
# fat boy
# au bon pain
# ohjah noodle house #2
# cinnabon
# thailicious
# bosss slow smoked bbq
# buon gusto ristorante

# %% [markdown]
# The simple solution is to remove the rows missing 'longitude' values, as they represent duplicate entries.

# %%
data.dropna(subset = ['longitude'], inplace = True)
data.reset_index(inplace = True, drop = True)

# %%
print('The dataset now has {0} rows and {1} columns of restaurant data.'.format(
    data.shape[0], 
    data.shape[1])
     )
# Out:
# The dataset now has 644070 rows and 8 columns of restaurant data.

# %% [markdown]
# #### A Quick Glance at Country Values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 644070 entries, 0 to 644069
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   restaurant_id  644070 non-null  object
#  1   name           644070 non-null  object
#  2   platform       644070 non-null  object
#  3   sub_platform   599295 non-null  object
#  4   latitude       644070 non-null  object
#  5   longitude      644070 non-null  object
#  6   country        644070 non-null  object
#  7   active         643850 non-null  object
# dtypes: object(8)
# memory usage: 39.3+ MB

# %%
data['country'].describe()
# Out:
# count     644070
# unique        27
# top           US
# freq      643890
# Name: country, dtype: object

# %% [markdown]
# Most of the data points have 'US' listed in the 'country' column, so there would be value in examining the rows in which this is not the case.

# %%
not_us_data = data[data['country'] != 'US']

not_us_data
# Out:
#                restaurant_id              name          platform  \
# 96549   ,USD,[[""open: 12:00   close: 20:30""]    [""open: 12:00
# 96958   ,USD,[[""open: 11:30   close: 20:00""]    [""open: 11:30
# 97841   ,USD,[[""open: 13:00   close: 23:00""]    [""open: 13:00
# 104012              ,USD,[[]                []                []
# 104302  ,USD,[[""open: 17:00   close: 23:30""]                []
# ...                      ...               ...               ...
# 426413  ,USD,[[""open: 17:00   close: 19:00""]    [""open: 17:00
# 428302              ,USD,[[]                []                []
# 431379  ,USD,[[""open: 14:00   close: 22:00""]    [""open: 14:00
# 433563              ,USD,[[]    [""open: 17:00   close: 20:00""]
# 440752  ,USD,[[""open: 11:00   close: 20:00""]    [""open: 11:00
#
#             sub_platform          latitude         longitude  \
# 96549    close: 20:30""]    [""open: 12:00   close: 20:30""]
# 96958    close: 20:00""]    [""open: 11:30   close: 20:00""]
# 97841    close: 23:00""]    [""open: 13:00   close: 23:00""]
# 104012                []                []                []
# 104302    [""open: 17:00   close: 23:00""]    [""open: 17:00
# ...                  ...               ...               ...
# 426413   close: 19:00""]    [""open: 17:00   close: 19:00""]
# 428302                []                []                []
# 431379   close: 22:00""]    [""open: 14:00   close: 22:00""]
# 433563    [""open: 17:00   close: 20:00""]    [""open: 18:30
# 440752   close: 20:00""]    [""open: 11:00   close: 20:00""]
#
#                  country            active
# 96549    close: 20:30""]   close: 20:30""]
# 96958    close: 20:00""]   close: 20:00""]
# 97841    close: 23:00""]   close: 00:00""]
# 104012             FALSE               NaN
# 104302    [""open: 17:00              []]"
# ...                  ...               ...
# 426413   close: 19:00""]   close: 21:30""]
# 428302             FALSE               NaN
# 431379   close: 22:00""]   close: 22:00""]
# 433563    [""open: 17:00    [""open: 17:00
# 440752   close: 20:00""]   close: 20:00""]
#
# [180 rows x 8 columns]

# %% [markdown]
# It seems possible that the rows of data that don't state 'US' in the country column are also filled with data that was entered or collected incorrectly.
#
# Upon observation, there seems to be a mix of restaurant hours, names, delivery radii, booleans, and NaNs found throughout this data.

# %%
strange_us_rows = ((644070 - 643890) / 644070) * 100
print(round(strange_us_rows, 3), '% of the dataset')
# Out:
# 0.028 % of the dataset

# %% [markdown]
# For the sake of time, because only 0.028% of the data is mislabeled as such, the appropriate solution at this time is to simply remove these data points.

# %%
data = data[data['country'] == 'US']

print('There are now {0} restaurants in the dataset and {1} columns of relevant data.'.format(
    data.shape[0], 
    data.shape[1])
     )
# Out:
# There are now 643890 restaurants in the dataset and 8 columns of relevant data.

# %% [markdown]
# #### Coordinates: Latitude
#
# At this stage my plan to solve the problem of identifying duplicates heavily relies upon the coordinate data (latitude and longitude) values of each restaurant.

# %%
data.dtypes
# Out:
# restaurant_id    object
# name             object
# platform         object
# sub_platform     object
# latitude         object
# longitude        object
# country          object
# active           object
# dtype: object

# %%
data.loc[0]
# Out:
# restaurant_id          9744
# name              loco coco
# platform             caviar
# sub_platform            NaN
# latitude          40.765004
# longitude        -73.965961
# country                  US
# active                 TRUE
# Name: 0, dtype: object

# %%
data['name'] = data['name'].astype('str')
data['platform'] = data['platform'].astype('str')
data['latitude'] = data['latitude'].astype('float')
data['longitude'] = data['longitude'].astype('float')

# %%
data['latitude'].value_counts(dropna = True).sort_values(ascending = False)
# Out:
# -90.000000    1683
#  40.762646     101
#  42.825685      80
#  34.039710      67
#  35.279820      66
#               ...
#  27.036954       1
#  33.996883       1
#  40.779721       1
#  33.998372       1
#  32.162496       1
# Name: latitude, Length: 544594, dtype: int64

# %% [markdown]
# Out of curiosity, I want to run the same observations on the longitude column.

# %%
data['longitude'].value_counts(dropna = False).sort_values(ascending = False)
# Out:
#  0.000000      1722
# -73.969185      101
# -118.298741     100
# -73.879458       80
# -118.298796      67
#                ...
# -122.433768       1
# -90.110298        1
# -117.048787       1
# -75.224099        1
# -81.751534        1
# Name: longitude, Length: 541745, dtype: int64

# %% [markdown]
# Interestingly, there are a lot of data points with a longitude value of 0. I will explore this further in a later section.

# %%
lat_90 = data[data['latitude'] == -90.000000]

print(lat_90)
# Out:
#       restaurant_id                name      platform sub_platform  latitude  \
# 60            59739          bequ juice  delivery.com          NaN     -90.0
# 64            63820          ginos east  delivery.com          NaN     -90.0
# 100           64603          sori sushi  delivery.com          NaN     -90.0
# 201           63305          ezras food  delivery.com          NaN     -90.0
# 212           57676   cupping room cafe  delivery.com          NaN     -90.0
# ...             ...                 ...           ...          ...       ...
# 44649            81  cozy soup n burger  delivery.com          NaN     -90.0
# 44691         61491              wichit  delivery.com          NaN     -90.0
# 44715         61250           fdgdfgdfg  delivery.com          NaN     -90.0
# 44740         58580           neo sushi  delivery.com          NaN     -90.0
# 44746         62673          moonstruck  delivery.com          NaN     -90.0
#
#        longitude country active
# 60           0.0      US  FALSE
# 64           0.0      US  FALSE
# 100          0.0      US  FALSE
# 201          0.0      US  FALSE
# 212          0.0      US  FALSE
# ...          ...     ...    ...
# 44649        0.0      US  FALSE
# 44691        0.0      US  FALSE
# 44715        0.0      US  FALSE
# 44740        0.0      US  FALSE
# 44746        0.0      US  FALSE
#
# [1683 rows x 8 columns]

# %%
lat_90['platform'].value_counts(dropna = False, normalize = True)
# Out:
# delivery.com    1.0
# Name: platform, dtype: float64

# %%
lat_90['active'].value_counts(dropna = False, normalize = True)
# Out:
# FALSE    1.0
# Name: active, dtype: float64

# %%
lat_90['longitude'].value_counts(dropna = False, normalize = True)
# Out:
# 0.0    1.0
# Name: longitude, dtype: float64

# %% [markdown]
# For all of the data points with a latitude value of -90, three interesting things the data points all have in common are:
#
# - All are considered "inactive"
# - All of these data points shared the platform delivery.com
# - All have a longitude value of 0

# %%
data['platform'].value_counts(dropna = False)
# Out:
# doordash        354553
# postmates       110242
# grubhub          68579
# ubereats         65741
# delivery.com     34807
# caviar            9968
# Name: platform, dtype: int64

# %% [markdown]
# Quickly checking that it's not an issue with all delivery.com data but just the ones found earlier.

# %%
data[data['platform'] == 'delivery.com']
# Out:
#       restaurant_id                                    name      platform  \
# 47            68986                     crown fried chicken  delivery.com
# 48            89239                        capri ristorante  delivery.com
# 49            73694                           fin sushi bar  delivery.com
# 50            86326               bon chon   harvard square  delivery.com
# 51            68391                               pizza man  delivery.com
# ...             ...                                     ...           ...
# 44772         61696                                  balade  delivery.com
# 44773         63702                             hello pasta  delivery.com
# 44774         71933  napoli italian restaurant by papa zack  delivery.com
# 44775         54099                               fatburger  delivery.com
# 44776         36134                              pita grill  delivery.com
#
#       sub_platform   latitude   longitude country active
# 47             NaN  40.634279  -73.949846      US  FALSE
# 48             NaN  41.865140  -87.789410      US   TRUE
# 49             NaN  41.965212  -87.673360      US   TRUE
# 50             NaN  42.371670  -71.121040      US   TRUE
# 51             NaN  33.931870 -117.949910      US   TRUE
# ...            ...        ...         ...     ...    ...
# 44772          NaN  40.730305  -73.983176      US   TRUE
# 44773          NaN  40.759411  -73.970211      US   TRUE
# 44774          NaN  29.731403  -95.475292      US   TRUE
# 44775          NaN  30.621215  -96.342298      US   TRUE
# 44776          NaN  40.764990  -73.987687      US   TRUE
#
# [34807 rows x 8 columns]

# %% [markdown]
# My suspicion is that the data represented incorrectly with latitude values of -90 may already exist in the data set somehow. I'll check that now with some quick searches through the data set.

# %%
data[data['name'] == 'bequ juice']
# Out:
#        restaurant_id        name      platform sub_platform   latitude  \
# 60             59739  bequ juice  delivery.com          NaN -90.000000
# 27394          73431  bequ juice  delivery.com          NaN  40.728651
# 39550          91771  bequ juice  delivery.com          NaN  40.728651
# 215698        289315  bequ juice       grubhub      grubhub  40.728275
#
#         longitude country active
# 60       0.000000      US  FALSE
# 27394  -73.986022      US   TRUE
# 39550  -73.986022      US   TRUE
# 215698 -73.985367      US   TRUE

# %% [markdown]
# It seems there is enough here to support my suspicions, as it seems like information on this platform was either updated and/or re-entered. However, if there is data present with name and platform data that doesn't have location data in the form of coordinates, I would have difficulty acquiring correct latitude and longitude data anyways. The time-sensitive solution is to simply remove the rows of data with missing latitude/longitude values.

# %% [markdown]
# I can remove the entries with -90 stated for their latitude values as they are simply not updated versions of data that exist already in the dataset.

# %%
data = data[data['latitude'] != -90.000000]

data['latitude'].value_counts(dropna = False)
# Out:
# 40.762646    101
# 42.825685     80
# 34.039710     67
# 35.279820     66
# 34.039743     61
#             ...
# 38.780604      1
# 37.160258      1
# 33.425420      1
# 47.487414      1
# 25.760583      1
# Name: latitude, Length: 544593, dtype: int64

# %% [markdown]
# #### Coordinates: Longitude

# %%
data['longitude'].value_counts(dropna = False).sort_values(ascending = False)
# Out:
# -73.969185     101
# -118.298741    100
# -73.879458      80
# -118.298796     67
# -120.661130     66
#               ...
# -122.433768      1
# -90.110298       1
# -117.048787      1
# -75.224099       1
# -81.751534       1
# Name: longitude, Length: 541745, dtype: int64

# %% [markdown]
# Earlier, I discovered many data points had a longitude value of 0. Removing the data points with latitude values of -90 should have removed many of the rows with longitude values of 0.

# %%
data[data['longitude'] == 0]
# Out:
#        restaurant_id                                       name      platform  \
# 137             5648                    jessica hui placeholder        caviar
# 160             1526                             the halal guys        caviar
# 312             2045                          zipchops   venice        caviar
# 325             6018                       red hot chili pepper        caviar
# 402             1229                                  duplicate        caviar
# 816             6060         [deprecated] saffron indian bistro        caviar
# 1016             653                                      blank        caviar
# 1589            9239                                  bonci dnu        caviar
# 2018            2277                   test only   dan schwartz        caviar
# 5569            6595                         bluestem brasserie        caviar
# 5674           10338                                 squaretest        caviar
# 6068             438                                the gryphon        caviar
# 6129            5012                                     testjh        caviar
# 6420             623                                      trash        caviar
# 6862            7249                                    manpuku        caviar
# 9105            6874                                libby pizza        caviar
# 10351            701                                      blank        caviar
# 10634          10367                                  plum cafe        caviar
# 10693           1260          zento trash bucket  do not enable        caviar
# 12074          61898                          pie eyed pizzeria  delivery.com
# 12875            382                      available merchant id        caviar
# 15747          90142                            dickeys bbq pit  delivery.com
# 16677           1919                      cheetos promo preview        caviar
# 16844           3308                                bird & bone        caviar
# 17415           3366                                viking soul        caviar
# 19858           6653                        disabled lama beans        caviar
# 20259           6932  [desprecated] basil thai restaurant & bar        caviar
# 21283           6841                               jessica test        caviar
# 22880           6316                                thai palace        caviar
# 23763           5972    eden silk road cuisine (reuse merchant)        caviar
# 24301            929                          michelles kitchen  delivery.com
# 27623           2525                                  nyc trash        caviar
# 27877          64749                         abhineet bhatnagar  delivery.com
# 30631            355                                       open        caviar
# 39902          63760                                bgg grocery  delivery.com
# 70081         404666         taco bueno  (6001 w interstate 40)      doordash
# 70233          27112                                  magic wok      doordash
# 110136        404513     bgr the burger joint  (towne ctr blvd)      doordash
# 115763        405297   charleys philly steaks  (clear creek rd)      doordash
#
#        sub_platform  latitude  longitude country active
# 137             NaN       0.0        0.0      US  FALSE
# 160             NaN       0.0        0.0      US  FALSE
# 312             NaN       0.0        0.0      US  FALSE
# 325             NaN       0.0        0.0      US  FALSE
# 402             NaN       0.0        0.0      US  FALSE
# 816             NaN       0.0        0.0      US  FALSE
# 1016            NaN       0.0        0.0      US  FALSE
# 1589            NaN       0.0        0.0      US  FALSE
# 2018            NaN       0.0        0.0      US  FALSE
# 5569            NaN       0.0        0.0      US  FALSE
# 5674            NaN       0.0        0.0      US  FALSE
# 6068            NaN       0.0        0.0      US  FALSE
# 6129            NaN       0.0        0.0      US  FALSE
# 6420            NaN       0.0        0.0      US  FALSE
# 6862            NaN       0.0        0.0      US  FALSE
# 9105            NaN       0.0        0.0      US  FALSE
# 10351           NaN       0.0        0.0      US  FALSE
# 10634           NaN       0.0        0.0      US  FALSE
# 10693           NaN       0.0        0.0      US  FALSE
# 12074           NaN       0.0        0.0      US  FALSE
# 12875           NaN       0.0        0.0      US  FALSE
# 15747           NaN       0.0        0.0      US  FALSE
# 16677           NaN       0.0        0.0      US  FALSE
# 16844           NaN       0.0        0.0      US  FALSE
# 17415           NaN       0.0        0.0      US  FALSE
# 19858           NaN       0.0        0.0      US  FALSE
# 20259           NaN       0.0        0.0      US  FALSE
# 21283           NaN       0.0        0.0      US  FALSE
# 22880           NaN       0.0        0.0      US  FALSE
# 23763           NaN       0.0        0.0      US  FALSE
# 24301           NaN       0.0        0.0      US  FALSE
# 27623           NaN       0.0        0.0      US  FALSE
# 27877           NaN       0.0        0.0      US  FALSE
# 30631           NaN       0.0        0.0      US  FALSE
# 39902           NaN       0.0        0.0      US  FALSE
# 70081      doordash       0.0        0.0      US  FALSE
# 70233      doordash       0.0        0.0      US  FALSE
# 110136     doordash       0.0        0.0      US  FALSE
# 115763     doordash       0.0        0.0      US  FALSE

# %% [markdown]
# There aren't very many rows with longitude values of 0, but interestingly the rows also have latitude values of 0. Upon closer inspection, there are a lot of restaurants with names that suggest they should not exist in the data set (e.g. "jessica hui placeholder", "jessica test"). I'll inspect the names of the restaurants more carefully later. For the time being, I will simply remove these rows as the most time-sensitive solution.

# %%
data = data[data['longitude'] != 0.0]

# %%
data[data['latitude'] == 0]
# Out:
# Empty DataFrame
# Columns: [restaurant_id, name, platform, sub_platform, latitude, longitude, country, active]
# Index: []

# %% [markdown]
# By getting rid of rows with longitude values of 0, I also happened to get rid of rows with latitude values of 0 as well.

# %% [markdown]
# #### Even Further Examination on Latitude and Longitude
#
# My final step is to check the latitude and longitude values to make sure they make logical sense. All data points represent restaurants in the US, so the latitude and longitude values should reflect that.
#
# According to the information found at this [link](https://latitudelongitude.org/us/), the range of latitude and longitude values for US cities should range from:
# - Latitude: 19.50139 to 64.85694
# - Longitude: -161.75583 to -68.01197
#
# I am also using this [website](https://www.gps-coordinates.net/) to quickly check my logic when appropriate with regards to the location of restaurants.
#
# With some simple boolean indexing, I can isolate and examine rows of values that do not come close to fitting in these general coordinates.

# %%
data[(data['latitude'] < 19)]
# Out:
#       restaurant_id                                      name      platform  \
# 4              5690                       derek test merchant        caviar
# 166            9812  the french bakery   112th ave [disabled]        caviar
# 637            9398                                  donotuse        caviar
# 907            9607                        [dnu] toms dim sum        caviar
# 913            1183                test doc ricketts catering        caviar
# 1461          10348                          pho viet 11th st        caviar
# 2430           7415                                pappasitos        caviar
# 2819          10316                       norah restaurant la        caviar
# 5596          10335                    india palace   alameda        caviar
# 5604           9364     donotusepepperoncini restaurant & bar        caviar
# 5663           9134                      [do not use] la viga        caviar
# 6772          10365                                holy cluck        caviar
# 6995          10155                      tangs pacific bistro        caviar
# 8804           8860          [do not use]sparkys pizza   nopo        caviar
# 8918          10176      smoke daddy bbq   wrigleyville   dnu        caviar
# 8928          10337                 flacos tacos   south loop        caviar
# 9092          10345             galveston restaurant and cafe        caviar
# 10272         10363                    takorean catering   dc        caviar
# 10365         10347                              pinkys pizza        caviar
# 10595         10255                                  donotuse        caviar
# 10635         10353                     hax hops & hamburgers        caviar
# 10709         10346                                 tasty bbq        caviar
# 12390         10334                                   hala in        caviar
# 12410          9280                                 duplicate        caviar
# 12469         10336                                  bonafini        caviar
# 13278          8861            [do not use]sparkys pizza   ne        caviar
# 14300         10333                                 bixi beer        caviar
# 14319          4077                                       olo        caviar
# 16197         10359                                     i tea        caviar
# 16217         10366                             sons addition        caviar
# 16220         10358                               tsuki sushi        caviar
# 16704         10324                                 hamiltons        caviar
# 16734          9294                                do not use        caviar
# 17484         10356                              destroyer la        caviar
# 19663          9301                                  donotuse        caviar
# 19866          9689                              test by hana        caviar
# 19892          9813    the french bakery   8th st. [disabled]        caviar
# 20181         10357                 norah restaurant la   dnu        caviar
# 21274         10349                             psychic wines        caviar
# 21728         63047                             ecorican cafe  delivery.com
# 23839         10362                             leaning tower        caviar
# 24505         10344                            brotzeit lokal        caviar
# 28976         10364                          stonemill matcha        caviar
# 29388         10360                                     bhuna        caviar
# 29391         10354                            camperdown elm        caviar
# 29776         10355           wok wok southeast asian kitchen        caviar
# 30276         10223                                  republic        caviar
# 46620         45735                                 mod pizza      doordash
#
#       sub_platform   latitude   longitude country active
# 4              NaN   1.000000    2.000000      US  FALSE
# 166            NaN   1.000000   -1.000000      US  FALSE
# 637            NaN  11.000000  -11.000000      US  FALSE
# 907            NaN  11.000000  -11.000000      US  FALSE
# 913            NaN   1.000000    2.000000      US  FALSE
# 1461           NaN   1.000000    1.000000      US  FALSE
# 2430           NaN   0.111111    0.111111      US  FALSE
# 2819           NaN   1.000000    1.000000      US  FALSE
# 5596           NaN   1.000000    1.000000      US  FALSE
# 5604           NaN  11.000000  -11.000000      US  FALSE
# 5663           NaN   1.000000    1.000000      US  FALSE
# 6772           NaN   1.000000    1.000000      US  FALSE
# 6995           NaN  11.000000  -11.000000      US  FALSE
# 8804           NaN   1.000000    1.000000      US  FALSE
# 8918           NaN   1.000000    1.000000      US  FALSE
# 8928           NaN   1.000000    1.000000      US  FALSE
# 9092           NaN   1.000000    1.000000      US  FALSE
# 10272          NaN   1.000000    1.000000      US  FALSE
# 10365          NaN   1.000000   -1.000000      US  FALSE
# 10595          NaN   1.000000    1.000000      US  FALSE
# 10635          NaN   1.000000    1.000000      US  FALSE
# 10709          NaN   1.000000   -1.000000      US  FALSE
# 12390          NaN   1.000000    1.000000      US  FALSE
# 12410          NaN  11.000000  -11.000000      US  FALSE
# 12469          NaN   1.000000    1.000000      US  FALSE
# 13278          NaN   1.000000    1.000000      US  FALSE
# 14300          NaN   1.000000    1.000000      US  FALSE
# 14319          NaN   1.000000    1.000000      US  FALSE
# 16197          NaN   1.000000   -1.000000      US  FALSE
# 16217          NaN   1.000000    1.000000      US  FALSE
# 16220          NaN   1.000000   -1.000000      US  FALSE
# 16704          NaN   1.000000    1.000000      US  FALSE
# 16734          NaN  11.000000  -11.000000      US  FALSE
# 17484          NaN   1.000000    1.000000      US  FALSE
# 19663          NaN   1.000000   -1.000000      US  FALSE
# 19866          NaN   1.000000    1.000000      US  FALSE
# 19892          NaN   1.000000   -1.000000      US  FALSE
# 20181          NaN   1.000000    1.000000      US  FALSE
# 21274          NaN   1.000000    1.000000      US  FALSE
# 21728          NaN  18.375054  -65.722797      US   TRUE
# 23839          NaN   1.000000    1.000000      US  FALSE
# 24505          NaN   1.000000    1.000000      US  FALSE
# 28976          NaN   1.000000    1.000000      US  FALSE
# 29388          NaN   1.000000   -1.000000      US  FALSE
# 29391          NaN   1.000000    1.000000      US  FALSE
# 29776          NaN   1.000000    1.000000      US  FALSE
# 30276          NaN  11.000000  -11.000000      US  FALSE
# 46620     doordash  14.215883  121.141894      US  FALSE

# %% [markdown]
# Examining strange coordinate data has in fact dug up an entirely new problem. At a glance, there are multiple rows of data with values for latitude and longitude that don't make much logical sense. When examining the names of said restuarants, one can see that many of the names of the restaurants include some form of:
# - "DO NOT USE"
# - "DISABLED"
# - "TEST"
#
# These need to be removed from the data set. Something to note is that all of the rows seen above that have one of the three ("DO NOT USE", "DISABLED", "TEST") labels on the respective restaurant name
# - Are not active restaurants
# - The platform is "caviar"
#
# It's possible that something related to that platform led to multiple users creating a version of their restaurant to test the functionality of the site/app/program before creating a normal profile, hence the strange location data. I'll explore this now.

# %% [markdown]
# #### Taking a Closer Look at the Names of Restaurants

# %%
import re

# %%
data[data['name'].str.contains('[Dd][Oo]\s*[Nn][Oo][Tt]\s*[Uu][Ss][Ee]')]
# Out:
#        restaurant_id                                               name  \
# 29              6878               chens chinese & cuisine {do not use}
# 164             5309                    hot wok bistro too (do not use)
# 350             9211                                         do not use
# 351             9370             [do not use] taylor gourmet   the loop
# 370             3778  california pizza kitchen   lenox square (do no...
# ...              ...                                                ...
# 565601        184479  duplicate do not use subway (2181 n meridian s...
# 594222         87297                      fuzzys tacos (coo do not use)
# 614478         37588             duplicate do not use american roadside
# 627323        314371                                         do not use
# 636999         56541                 krush burger, do not use, dup acct
#
#         platform sub_platform   latitude   longitude country active
# 29        caviar          NaN  41.888853  -87.633035      US  FALSE
# 164       caviar          NaN  37.495809 -122.247895      US  FALSE
# 350       caviar          NaN  41.877671  -87.646821      US  FALSE
# 351       caviar          NaN  41.882225  -87.628988      US  FALSE
# 370       caviar          NaN  33.846469  -84.362657      US  FALSE
# ...          ...          ...        ...         ...     ...    ...
# 565601  doordash     doordash  39.797165  -86.156953      US  FALSE
# 594222  doordash     doordash  29.671878  -95.460527      US  FALSE
# 614478  doordash     doordash  35.152501  -80.841481      US  FALSE
# 627323  doordash     doordash  43.777990  -79.344091      US  FALSE
# 636999  doordash     doordash  38.773442 -121.269283      US   TRUE
#
# [146 rows x 8 columns]

# %% [markdown]
# By using regular expressions (regex), we can see that there are other versions/formats that are all basically saying the same thing: to remove the row in question from the data set. I will explore more in the code below.

# %%
# a closer look at the string "DO NOT"

data[data['name'].str.contains('[Dd][Oo]\s*[Nn][Oo][Tt]\s*')]
# Out:
#        restaurant_id                                               name  \
# 29              6878               chens chinese & cuisine {do not use}
# 30              8216                  king��s road cafe   do not enable
# 139             5074                  yucatan taco stand  do not enable
# 143             3700  [do not enable, bad duplicate] meehans (sandy ...
# 159              725                        phuong thao [do not enable]
# ...              ...                                                ...
# 627323        314371                                         do not use
# 631284        248591  do not activate jnovaks house of ceviche & man...
# 636574         71432           jaburritos   duplicate   do not activate
# 636999         56541                 krush burger, do not use, dup acct
# 640228         93754                         mama fus (do not activate)
#
#         platform sub_platform   latitude   longitude country active
# 29        caviar          NaN  41.888853  -87.633035      US  FALSE
# 30        caviar          NaN  34.076246 -118.372312      US  FALSE
# 139       caviar          NaN  32.815272  -96.770349      US  FALSE
# 143       caviar          NaN  33.839531  -84.377089      US  FALSE
# 159       caviar          NaN  37.376854 -122.030459      US  FALSE
# ...          ...          ...        ...         ...     ...    ...
# 627323  doordash     doordash  43.777990  -79.344091      US  FALSE
# 631284  doordash     doordash  33.415009 -111.949098      US   TRUE
# 636574  doordash     doordash  36.078083 -115.242157      US  FALSE
# 636999  doordash     doordash  38.773442 -121.269283      US   TRUE
# 640228  doordash     doordash  29.603282  -95.127123      US  FALSE
#
# [278 rows x 8 columns]

# %% [markdown]
# There appear to be multiple ways that rows in the data set are denoted to be excluded. While we observed "DO NOT USE" earlier, there appear to be other statements in restaurant names that tell us the same thing (e.g. "DO NOT ENABLE", "DO NOT ACTIVATE").

# %%
# looking at names with the word "duplicate" in said names

data[data['name'].str.contains('[Dd][Uu][Pp][Ll][Ii][Cc][Aa][Tt][Ee]')]
# Out:
#        restaurant_id                                               name  \
# 143             3700  [do not enable, bad duplicate] meehans (sandy ...
# 152              601                            tiffin bistro duplicate
# 155              803                 pure fare   south street duplicate
# 579             6691             via tribunali   queen anne [duplicate]
# 953             3698  [do not enable, bad duplicate] willys mexicana...
# ...              ...                                                ...
# 643565        154607                            papa murphys  duplicate
# 643595        237367      papa murphys (star shoot parkway)   duplicate
# 643627        253513                       kreasian kitchen   duplicate
# 643780        254426            papa murphys (state street)   duplicate
# 644062        253594                    h salt fish & chips   duplicate
#
#         platform sub_platform   latitude   longitude country active
# 143       caviar          NaN  33.839531  -84.377089      US  FALSE
# 152       caviar          NaN  39.934720  -75.162219      US  FALSE
# 155       caviar          NaN  39.944246  -75.169180      US  FALSE
# 579       caviar          NaN  47.632169 -122.361350      US  FALSE
# 953       caviar          NaN  33.783865  -84.378648      US  FALSE
# ...          ...          ...        ...         ...     ...    ...
# 643565  doordash     doordash  40.113446  -88.203063      US  FALSE
# 643595  doordash     doordash  38.024013  -84.424365      US  FALSE
# 643627  doordash     doordash  34.278121 -118.736263      US  FALSE
# 643780  doordash     doordash  38.306181  -85.842397      US  FALSE
# 644062  doordash     doordash  34.283007 -118.439891      US  FALSE
#
# [5158 rows x 8 columns]

# %% [markdown]
# We can see now that some restaurants can be labeled as duplicates without "DO NOT" also attached to their names (and vise-versa).

# %%
# also searching for the word "copy" which is synonymous for "duplicate"

data[data['name'].str.contains('[Cc][Oo][Pp][Yy]')]
# Out:
#                                restaurant_id  \
# 840                                     2287
# 4294                                   73842
# 4815                                   79618
# 12710                                  66141
# 14127                                  64996
# 15354                                  73746
# 16833                                   2138
# 20000                                  79654
# 22010                                  71391
# 24946                                  63955
# 25896                                  79058
# 30528                                  87866
# 33966                                  79764
# 38913                                  63512
# 42036                                  66266
# 332502                                235929
# 425725  5b4ed7aa-ad1f-4714-9de8-77a015b42a3c
#
#                                                      name      platform  \
# 840                                         cafe ole copy        caviar
# 4294                            choppers   infocache copy  delivery.com
# 4815    duplicate   copy of masters pizza pasta & gril...  delivery.com
# 12710   duplicate   copy of peking express before kgis...  delivery.com
# 14127   joannes import staging listing   for appending...  delivery.com
# 15354      (temp / test duplicate) copy of my thai rboyce  delivery.com
# 16833                     naan n curry (2nd copy, unused)        caviar
# 20000            duplicate   copy of wolfnights rid 67892  delivery.com
# 22010                  sample restaurant testing copyover  delivery.com
# 24946                            mama mia #69568 copyover  delivery.com
# 25896       copy of menu for dozika restaurant rid: 74098  delivery.com
# 30528     duplicate   copy back up of the quick fixx menu  delivery.com
# 33966   duplicate   copy of las olas sushi bar to be u...  delivery.com
# 38913         the classic diner (copy of original update)  delivery.com
# 42036                   katzs delicatessen range copyover  delivery.com
# 332502                                         copycat co      doordash
# 425725                              trademark & copyright      ubereats
#
#        sub_platform   latitude   longitude country active
# 840             NaN  38.941704  -77.077104      US  FALSE
# 4294            NaN  41.911545  -87.667617      US  FALSE
# 4815            NaN  34.097480 -118.338670      US  FALSE
# 12710           NaN  40.741802  -73.990555      US  FALSE
# 14127           NaN  40.762646  -73.969185      US  FALSE
# 15354           NaN  32.755044 -117.099129      US  FALSE
# 16833           NaN  37.764284 -122.464891      US  FALSE
# 20000           NaN  34.062306 -118.350917      US  FALSE
# 22010           NaN  40.762646  -73.969185      US  FALSE
# 24946           NaN  40.703276  -74.009694      US  FALSE
# 25896           NaN  34.043040 -118.323560      US   TRUE
# 30528           NaN  39.943976  -75.167998      US   TRUE
# 33966           NaN  34.102520 -118.291860      US  FALSE
# 38913           NaN  40.703276  -74.009694      US  FALSE
# 42036           NaN  40.750034  -74.026457      US  FALSE
# 332502     doordash  38.900414  -76.991026      US   TRUE
# 425725     ubereats  37.776081 -122.408346      US   TRUE

# %% [markdown]
# While it is obvious that many of the restaurants with "copy" in their name are indeed duplicates, a few restaurants have "copy" in their actual names (e.g. "Copycat Co"). An interesting bit of text that some restaurants have included in their 'name' values is "UPDATE". I will explore this more below.

# %%
data[data['name'].str.contains('[Uu][Pp][Dd][Aa][Tt][Ee]')]
# Out:
#       restaurant_id                                               name  \
# 4815          79618  duplicate   copy of masters pizza pasta & gril...
# 9987          64847      gracies corner diner   updated menu test acct
# 10515         64003    bon chon chicken   fake restaurant  10/9 update
# 12710         66141  duplicate   copy of peking express before kgis...
# 15297         79429  duplicate   menu update for thai dishes   hold...
# 22225         64414  duplicate   5th china tung before kgisl menu u...
# 26448         79208                  updated menu for als italian beef
# 32029         79518           red pepper pizza back up of updated menu
# 32632         30869                 color me greens   update for 10/1.
# 33966         79764  duplicate   copy of las olas sushi bar to be u...
# 35162         60980  eddy catering (update that were inputting from...
# 37619         91660                               afternoon tea update
# 38913         63512        the classic diner (copy of original update)
#
#            platform sub_platform   latitude   longitude country active
# 4815   delivery.com          NaN  34.097480 -118.338670      US  FALSE
# 9987   delivery.com          NaN  40.777749  -73.951775      US  FALSE
# 10515  delivery.com          NaN  40.703276  -74.009694      US  FALSE
# 12710  delivery.com          NaN  40.741802  -73.990555      US  FALSE
# 15297  delivery.com          NaN  41.952821  -87.677771      US   TRUE
# 22225  delivery.com          NaN  27.110374  -80.308038      US  FALSE
# 26448  delivery.com          NaN  41.869304  -87.663019      US  FALSE
# 32029  delivery.com          NaN  40.682571  -73.993097      US   TRUE
# 32632  delivery.com          NaN  40.703276  -74.009694      US   TRUE
# 33966  delivery.com          NaN  34.102520 -118.291860      US  FALSE
# 35162  delivery.com          NaN  40.753786  -73.989773      US  FALSE
# 37619  delivery.com          NaN  42.825685  -73.879458      US   TRUE
# 38913  delivery.com          NaN  40.703276  -74.009694      US  FALSE

# %% [markdown]
# While some of these restaurant names make it very clear that they are copies or duplicates of entries, "update" is not as clear. Update could suggest changes to menus, locations, names, etc. I will revisit this later.

# %%
data[data['name'].str.contains('[Tt][Ee][Ss][Tt]')]
# Out:
#        restaurant_id                                        name  \
# 4               5690                         derek test merchant
# 627             3879                 nickys test [do not enable]
# 685            64095  sample restaurant for testing complex menu
# 878             3542            [test2]sugarfish by sushi nozawa
# 913             1183                  test doc ricketts catering
# ...              ...                                         ...
# 639531         50988                              dep test store
# 639594        392005                      novadine v2 test store
# 639862        330076                                        test
# 642231        230772                   testo pepesto (e main st)
# 643046        334544                              greatest b b q
#
#             platform sub_platform   latitude   longitude country active
# 4             caviar          NaN   1.000000    2.000000      US  FALSE
# 627           caviar          NaN  37.775231 -122.417528      US  FALSE
# 685     delivery.com          NaN  40.760541  -73.970354      US  FALSE
# 878           caviar          NaN  40.703738  -73.638472      US  FALSE
# 913           caviar          NaN   1.000000    2.000000      US  FALSE
# ...              ...          ...        ...         ...     ...    ...
# 639531      doordash     doordash  43.638283  -79.425290      US   TRUE
# 639594      doordash     doordash  58.372186 -134.587152      US   TRUE
# 639862      doordash     doordash  33.495742  -86.876172      US   TRUE
# 642231      doordash     doordash  32.794609 -116.959992      US   TRUE
# 643046      doordash     doordash  29.592922  -95.527972      US   TRUE
#
# [475 rows x 8 columns]

# %% [markdown]
# As seen above (e.g. "Testo Pepesto", "Greatest B-B-Q") filtering out restaurants for having some form of "TEST" in its name may not accurately weed out duplicates. I can adjust the regex in a later stage, but filtering by "TEST" must be done more carefully.

# %% [markdown]
# #### Removing Rows by Name
#
# It's evident that there are a number of rows in the data set calling for exclusion. As seen above, many duplicates exist that can be simply filtered out using some simple regular expressions (regex). I intend to:
# - Remove rows with some version/format of the string "Duplicate" (Since over 5000 rows of data include this in their restaurant name)
# - Remove rows with some version/format of the string "Do Not" (Multiple ways of denoting the need for exclusion from the data set exist, including but not limited to "do not use", "do not activate", "do not enable")
# - Re-examine restaurants with some version/format of the following strings in their respective name:
#     - "update"
#     - "sample"
#     - "copy"
#     - "test"

# %%
# removing restaurants with some form of "duplicate" in its name
data = data[data['name'].str.contains('[Dd][Uu][Pp][Ll][Ii][Cc][Aa][Tt][Ee]') == False]
print('The dataset now has {0} rows and {1} columns of restaurant data.'.format(
    data.shape[0], 
    data.shape[1])
     )
# Out:
# The dataset now has 637010 rows and 8 columns of restaurant data.

# %%
# removing restaurants with some form of "do not" in its name
data = data[data['name'].str.contains('[Dd][Oo]\s*[Nn][Oo][Tt]\s*') == False]
print('The dataset now has {0} rows and {1} columns of restaurant data.'.format(
    data.shape[0], 
    data.shape[1])
     )
# Out:
# The dataset now has 636772 rows and 8 columns of restaurant data.

# %% [markdown]
# ##### Re-Examining Restaurants w/ Some Form of "update" in its Name

# %%
data[data['name'].str.contains('[Uu][Pp][Dd][Aa][Tt][Ee]')]
# Out:
#       restaurant_id                                               name  \
# 9987          64847      gracies corner diner   updated menu test acct
# 10515         64003    bon chon chicken   fake restaurant  10/9 update
# 26448         79208                  updated menu for als italian beef
# 32029         79518           red pepper pizza back up of updated menu
# 32632         30869                 color me greens   update for 10/1.
# 35162         60980  eddy catering (update that were inputting from...
# 37619         91660                               afternoon tea update
# 38913         63512        the classic diner (copy of original update)
#
#            platform sub_platform   latitude  longitude country active
# 9987   delivery.com          NaN  40.777749 -73.951775      US  FALSE
# 10515  delivery.com          NaN  40.703276 -74.009694      US  FALSE
# 26448  delivery.com          NaN  41.869304 -87.663019      US  FALSE
# 32029  delivery.com          NaN  40.682571 -73.993097      US   TRUE
# 32632  delivery.com          NaN  40.703276 -74.009694      US   TRUE
# 35162  delivery.com          NaN  40.753786 -73.989773      US  FALSE
# 37619  delivery.com          NaN  42.825685 -73.879458      US   TRUE
# 38913  delivery.com          NaN  40.703276 -74.009694      US  FALSE

# %% [markdown]
# It seems pretty obvious that all of these rows can be removed because the data already exists in the data set. There aren't many rows, so I'll demonstrate below how each restaurant in the dataframe above is a repeat of an existing data point.

# %%
data[data['name'] == 'gracies corner diner']
# Out:
#        restaurant_id                  name  platform sub_platform   latitude  \
# 109157         66226  gracies corner diner   grubhub      grubhub  40.777123
# 608910         54903  gracies corner diner  doordash     doordash  40.776840
#
#         longitude country active
# 109157 -73.949970      US   TRUE
# 608910 -73.949756      US   TRUE

# %%
data[data['name'] == 'bon chon chicken']
# Out:
#                                restaurant_id              name      platform  \
# 39492                                  92571  bon chon chicken  delivery.com
# 100013                                297759  bon chon chicken       grubhub
# 216793  47cc5230-84bd-432e-b2b9-3807a800cd02  bon chon chicken     postmates
# 389234  5ada474d-609a-4ef2-9dd5-4a02c2d0d00b  bon chon chicken     postmates
#
#        sub_platform   latitude   longitude country active
# 39492           NaN  40.747378  -73.985193      US   TRUE
# 100013      grubhub  40.747338  -73.985088      US   TRUE
# 216793   restaurant  37.371954 -121.846143      US   TRUE
# 389234   restaurant  37.362701 -122.026382      US  FALSE

# %%
data[data['name'] == 'afternoon tea']
# Out:
#      restaurant_id           name      platform sub_platform   latitude  \
# 1109         91688  afternoon tea  delivery.com          NaN  42.825685
#
#       longitude country active
# 1109 -73.879458      US  FALSE

# %%
data[data['name'] == 'color me greens']
# Out:
#       restaurant_id             name      platform sub_platform   latitude  \
# 39588         83868  color me greens  delivery.com          NaN  40.699230
# 98149        309741  color me greens       grubhub      grubhub  40.699195
#
#        longitude country active
# 39588 -73.912720      US   TRUE
# 98149 -73.912966      US   TRUE

# %% [markdown]
# I will filter the data set and remove these rows from my original data set.

# %%
# removing restaurants with some form of "duplicate" in its name
data = data[data['name'].str.contains('[Uu][Pp][Dd][Aa][Tt][Ee]') == False]
print('The dataset now has {0} rows and {1} columns of restaurant data.'.format(
    data.shape[0], 
    data.shape[1])
     )
# Out:
# The dataset now has 636764 rows and 8 columns of restaurant data.

# %% [markdown]
# ##### Re-Examining Restaurants w/ Some Form of "sample" in its Name

# %%
data[(data['name'].str.contains('sample'))]
# Out:
#        restaurant_id                                        name  \
# 685            64095  sample restaurant for testing complex menu
# 764            88213                  sprightliis sample bagelry
# 2968           64529                            (sample) italian
# 4462           68437   sample restaurant   carlos   jira testing
# 4487           71056                           sample smoke shop
# ...              ...                                         ...
# 537881        211430               beijing express (e sample rd)
# 578563        420740                  nonnas pizza (w sample rd)
# 579735        262939               tijuana flats (w. sample rd.)
# 597718        262910                     la granja (w sample rd)
# 615093        105538     its all greek to me grill (w sample rd)
#
#             platform sub_platform   latitude  longitude country active
# 685     delivery.com          NaN  40.760541 -73.970354      US  FALSE
# 764     delivery.com          NaN  40.760541 -73.970354      US  FALSE
# 2968    delivery.com          NaN  41.714577 -83.684994      US   TRUE
# 4462    delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 4487    delivery.com          NaN  42.825685 -73.879458      US  FALSE
# ...              ...          ...        ...        ...     ...    ...
# 537881      doordash     doordash  26.274961 -80.116230      US   TRUE
# 578563      doordash     doordash  26.272976 -80.263821      US   TRUE
# 579735      doordash     doordash  26.272877 -80.205693      US   TRUE
# 597718      doordash     doordash  26.274350 -80.134681      US   TRUE
# 615093      doordash     doordash  26.272743 -80.197497      US   TRUE
#
# [84 rows x 8 columns]

# %% [markdown]
# At a glance, I want to differentiate between results for the platform delivery.com and doordash. There seems to be a pattern with restaurant names including the word "sample" that are listed on the doordash platform.

# %%
data[(data['name'].str.contains('sample')) & (data['platform'] == 'delivery.com')]
# Out:
#       restaurant_id                                               name  \
# 685           64095         sample restaurant for testing complex menu
# 764           88213                         sprightliis sample bagelry
# 2968          64529                                   (sample) italian
# 4462          68437          sample restaurant   carlos   jira testing
# 4487          71056                                  sample smoke shop
# 4632          66521                  sample restaurant   argenis genao
# 4711          62133  sample foodfriendz (florida) beverages & utensils
# 6169          71055         sample restaurant   marincorpsolutions.com
# 6226          64849  fake restaurant for tara leuci   test/sample/t...
# 9078          75107                        sample restaurant   testing
# 10456         68989                                   sample plu store
# 10793         37915                        sample restaurant   for nod
# 11305         71089              sample restaurant   infocachecorp.com
# 11371         71006                 sample restaurant   idata entry us
# 13554         67520             tiquillia mcperebo   sample restaurant
# 13656         71151  sample restaurant   neville pereira   infocach...
# 13945         57348                                  sample restaurant
# 14009         70314                     sample restaurant   rich boyce
# 14111         69545                sample restaurant   nicole williams
# 15369         67970                      sprightliis sample restaurant
# 15624         68988                                   sample plu store
# 16362         71154    sample restaurant   guli rajani   infocache.com
# 18107         71092              sample restaurant   ebusinessware.com
# 18301         68564                  sample restaurant   travis ferman
# 18872         71152  sample restaurant   gautam asudani   infocache...
# 21661         64132                           sprightliis sample diner
# 21950         60864                         firehouse subs sample road
# 22010         71391                 sample restaurant testing copyover
# 23114         71690              sutton wine shop   sample for testing
# 23909         72650            marina gourmet deli   sample restaurant
# 27842         66149                        richard sample restaurant 2
# 27882         69511                     sample restaurant   reviewer 1
# 29062         64531                                   (sample) mexican
# 31089         69657                         sample restaurant   tamika
# 31332         73523      sample restaurant    testing   anatolia issue
# 31885         68471                     sample restaurant   btl harlem
# 32133         71541             yash wine & liquors sis sample listing
# 32452         57551                                sample liquor store
# 32522         71513             yash wine & liquors upc sample listing
# 32734         58326                          sample freakin restaurant
# 33897         88671                     sprightlii 4 sample restaurant
# 35597         61061        sample restaurant for testing sanity checks
# 37723         68684                     sample restaurant   reviewer 2
# 39034         69318        pinkberry sample listing   work in progress
# 39781         57382                               sample restaurant ii
# 40289         64134             sample bagel store   complex menu tool
# 41081         89253        kennys deli sample for sprightlii to review
# 41339         69546                     sample restaurant   mike bruno
# 41532         88672                     sprightlii 5 sample restaurant
# 41800         68878                  sample restaurant   matthew brown
# 42531         64798                         papa johns sample template
# 43301         88214                        sprightliis sample pizzeria
# 43366         66452                                  sample restaurant
# 43645         71090              sample restaurant   unitywebgroup.com
# 44453          8406                            sample restaurant   rep
#
#            platform sub_platform   latitude  longitude country active
# 685    delivery.com          NaN  40.760541 -73.970354      US  FALSE
# 764    delivery.com          NaN  40.760541 -73.970354      US  FALSE
# 2968   delivery.com          NaN  41.714577 -83.684994      US   TRUE
# 4462   delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 4487   delivery.com          NaN  42.825685 -73.879458      US  FALSE
# 4632   delivery.com          NaN  40.760541 -73.970354      US  FALSE
# 4711   delivery.com          NaN  30.626630 -96.333424      US  FALSE
# 6169   delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 6226   delivery.com          NaN  40.737710 -73.987949      US  FALSE
# 9078   delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 10456  delivery.com          NaN  42.825685 -73.879458      US  FALSE
# 10793  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 11305  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 11371  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 13554  delivery.com          NaN  40.760541 -73.970354      US  FALSE
# 13656  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 13945  delivery.com          NaN  40.760541 -73.970354      US   TRUE
# 14009  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 14111  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 15369  delivery.com          NaN  40.738119 -73.988113      US  FALSE
# 15624  delivery.com          NaN  42.825685 -73.879458      US  FALSE
# 16362  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 18107  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 18301  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 18872  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 21661  delivery.com          NaN  40.760541 -73.970354      US  FALSE
# 21950  delivery.com          NaN  26.274034 -80.197916      US   TRUE
# 22010  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 23114  delivery.com          NaN  40.759234 -73.970071      US  FALSE
# 23909  delivery.com          NaN  40.738356 -73.982067      US  FALSE
# 27842  delivery.com          NaN  42.810107 -73.951075      US  FALSE
# 27882  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 29062  delivery.com          NaN  41.659383 -83.728458      US   TRUE
# 31089  delivery.com          NaN  40.762646 -73.969185      US   TRUE
# 31332  delivery.com          NaN  40.762646 -73.969185      US   TRUE
# 31885  delivery.com          NaN  40.738082 -73.988011      US  FALSE
# 32133  delivery.com          NaN  40.748600 -74.027525      US  FALSE
# 32452  delivery.com          NaN  40.706889 -74.004271      US   TRUE
# 32522  delivery.com          NaN  40.748600 -74.027525      US  FALSE
# 32734  delivery.com          NaN  40.762654 -73.969233      US  FALSE
# 33897  delivery.com          NaN  40.738119 -73.988113      US   TRUE
# 35597  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 37723  delivery.com          NaN  40.760541 -73.970354      US  FALSE
# 39034  delivery.com          NaN  40.740529 -73.982081      US  FALSE
# 39781  delivery.com          NaN  39.070682 -94.608825      US   TRUE
# 40289  delivery.com          NaN  40.760541 -73.970354      US  FALSE
# 41081  delivery.com          NaN  40.751403 -73.983757      US  FALSE
# 41339  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 41532  delivery.com          NaN  40.738119 -73.988113      US  FALSE
# 41800  delivery.com          NaN  40.738082 -73.988011      US   TRUE
# 42531  delivery.com          NaN  40.760541 -73.970354      US  FALSE
# 43301  delivery.com          NaN  40.760541 -73.970354      US  FALSE
# 43366  delivery.com          NaN  40.760541 -73.970354      US   TRUE
# 43645  delivery.com          NaN  40.762646 -73.969185      US   TRUE
# 44453  delivery.com          NaN  40.762646 -73.969185      US   TRUE

# %% [markdown]
# Many of the restaurants with the word "sample" in their name from delivery.com look like data points that can and should be removed. For example, "sample freakin restaurant" or "sample liquor store" may represent actual restaurants, but in all likelihood these are useless rows of data saturating the data set. Another clue into the uselessness of the rows above can also be the similarity in latitude and longitude values of these sample rows. It is logically impossible for multiple places to be found on the exact same latitude and longitude coordinates.
#
# Let's take a look at restaurants with the word "sample" that are not from delivery.com below.

# %%
data[(data['name'].str.contains('sample')) & (data['platform'] != 'delivery.com')]
# Out:
#        restaurant_id                                               name  \
# 77520         191105                                    the sample room
# 120311        851337                              subway� (w sample rd)
# 167215        548795                                 samples restaurant
# 201848        332484       miami grill   sample road (5650 w sample rd)
# 210168        249950         sofias cafe on sample home of sheesk kabab
# 217886        366240                    pinto thai bistro (e sample rd)
# 300334        262896                       firehouse subs (w sample rd)
# 336442        262894                             checkers (w sample rd)
# 358261        105883                        the melting pot (sample rd)
# 389883        113995                            red lantern (sample rd)
# 422577        124266                       samples restaurant (main st)
# 452485        106019                         khana khzana (w sample rd)
# 460064        262921                            mcdonalds (w sample rd)
# 460733        263000                       taco bell (east sample road)
# 463223        332592                       taco loco (1058 w sample rd)
# 469270        335666                       subway (57812) (w sample rd)
# 473871        255090                           firegrills (w sample rd)
# 482210        220474               bawarchi indian cusine (w sample rd)
# 511170        262995                            taco bell (w sample rd)
# 511800        262925                            mcdonalds (w sample rd)
# 523590        262942                            starbucks (w sample rd)
# 527767        105664            el balcon de las americas (w sample rd)
# 529500        262898  golden krust caribbean bakery & grill (sample rd)
# 537170        211337            sal��s italian ristorante (w sample rd)
# 537881        211430                      beijing express (e sample rd)
# 578563        420740                         nonnas pizza (w sample rd)
# 579735        262939                      tijuana flats (w. sample rd.)
# 597718        262910                            la granja (w sample rd)
# 615093        105538            its all greek to me grill (w sample rd)
#
#         platform sub_platform   latitude   longitude country active
# 77520   doordash     doordash  45.009552  -93.271988      US   TRUE
# 120311   grubhub      grubhub  26.272694  -80.162766      US   TRUE
# 167215   grubhub      grubhub  40.165287 -105.102112      US   TRUE
# 201848  doordash     doordash  26.273810  -80.201406      US   TRUE
# 210168  doordash     doordash  26.272481  -80.231649      US   TRUE
# 217886  doordash     doordash  26.275173  -80.109766      US   TRUE
# 300334  doordash     doordash  26.273460  -80.198948      US   TRUE
# 336442  doordash     doordash  26.272890  -80.259204      US   TRUE
# 358261  doordash     doordash  26.272117  -80.264381      US   TRUE
# 389883  doordash     doordash  26.275351  -80.134457      US   TRUE
# 422577  doordash     doordash  40.165289 -105.102114      US   TRUE
# 452485  doordash     doordash  26.272957  -80.264204      US   TRUE
# 460064  doordash     doordash  26.274434  -80.132260      US   TRUE
# 460733  doordash     doordash  26.275811  -80.099606      US   TRUE
# 463223  doordash     doordash  26.274368  -80.137032      US   TRUE
# 469270  doordash     doordash  26.272693  -80.162765      US   TRUE
# 473871  doordash     doordash  26.272823  -80.184383      US   TRUE
# 482210  doordash     doordash  26.272072  -80.262187      US   TRUE
# 511170  doordash     doordash  26.273239  -80.278921      US   TRUE
# 511800  doordash     doordash  26.273454  -80.281914      US   TRUE
# 523590  doordash     doordash  26.272985  -80.205697      US   TRUE
# 527767  doordash     doordash  26.271731  -80.231866      US   TRUE
# 529500  doordash     doordash  26.272496  -80.209118      US   TRUE
# 537170  doordash     doordash  26.272507  -80.210543      US   TRUE
# 537881  doordash     doordash  26.274961  -80.116230      US   TRUE
# 578563  doordash     doordash  26.272976  -80.263821      US   TRUE
# 579735  doordash     doordash  26.272877  -80.205693      US   TRUE
# 597718  doordash     doordash  26.274350  -80.134681      US   TRUE
# 615093  doordash     doordash  26.272743  -80.197497      US   TRUE

# %% [markdown]
# These rows of data are actually meaningful. The majority of these data points have the text "sample" in their names because they are located on Sample Rd in Coral Springs, Florida. This explains why the coordinates for most of these restaurants are very close together and yet different.
#
# It makes sense to remove the rows of data with the word "sample" only if that data point happens to be on the delivery.com platform.

# %%
# removing restaurants with some form of "sample" in its name & hosted on the platform delivery.com
data = data[(data['name'].str.contains('sample')) & (data['platform'] == 'delivery.com') == False]
print('The dataset now has {0} rows and {1} columns of restaurant data.'.format(
    data.shape[0], 
    data.shape[1])
     )
# Out:
# The dataset now has 636709 rows and 8 columns of restaurant data.

# %% [markdown]
# ##### Re-Examining Restaurants w/ Some Form of "copy" in its Name

# %%
data[data['name'].str.contains('copy')]
# Out:
#                                restaurant_id  \
# 840                                     2287
# 4294                                   73842
# 14127                                  64996
# 16833                                   2138
# 24946                                  63955
# 25896                                  79058
# 42036                                  66266
# 332502                                235929
# 425725  5b4ed7aa-ad1f-4714-9de8-77a015b42a3c
#
#                                                      name      platform  \
# 840                                         cafe ole copy        caviar
# 4294                            choppers   infocache copy  delivery.com
# 14127   joannes import staging listing   for appending...  delivery.com
# 16833                     naan n curry (2nd copy, unused)        caviar
# 24946                            mama mia #69568 copyover  delivery.com
# 25896       copy of menu for dozika restaurant rid: 74098  delivery.com
# 42036                   katzs delicatessen range copyover  delivery.com
# 332502                                         copycat co      doordash
# 425725                              trademark & copyright      ubereats
#
#        sub_platform   latitude   longitude country active
# 840             NaN  38.941704  -77.077104      US  FALSE
# 4294            NaN  41.911545  -87.667617      US  FALSE
# 14127           NaN  40.762646  -73.969185      US  FALSE
# 16833           NaN  37.764284 -122.464891      US  FALSE
# 24946           NaN  40.703276  -74.009694      US  FALSE
# 25896           NaN  34.043040 -118.323560      US   TRUE
# 42036           NaN  40.750034  -74.026457      US  FALSE
# 332502     doordash  38.900414  -76.991026      US   TRUE
# 425725     ubereats  37.776081 -122.408346      US   TRUE

# %%
# defining a function to quickly check for copies of restaurants using their names

def check_reentries(name):
    df = data[data['name'] == name]
    if df.shape[0] > 1:
        return True
    if df.shape[0] == 1:
        return False
    else:
        return print(df.shape)

# %%
# checking if duplicates exist for the doordash and ubereats listings
print(check_reentries('copycat co'))
print(check_reentries('trademark & copyright'))
# Out:
# False
# False

# %% [markdown]
# "copycat co" and "trademark & copyright" appear to be unique restaurants in the data set and therefore should be left in.

# %%
# checking if duplicates exist for the caviar listings
print(check_reentries('cafe ole'))
print(check_reentries('naan n curry'))
# Out:
# True
# True

# %%
data[data['name'] == 'cafe ole']
# Out:
#                                restaurant_id      name      platform  \
# 28407                                  81218  cafe ole  delivery.com
# 30483                                   4658  cafe ole        caviar
# 32915                                  81219  cafe ole  delivery.com
# 33210                                  76750  cafe ole  delivery.com
# 79695                                  10643  cafe ole      doordash
# 117865                                299842  cafe ole      doordash
# 193039  a89be976-07ed-4e81-af40-841a2d4b8722  cafe ole      ubereats
# 511555                                250540  cafe ole      doordash
# 539374                                216075  cafe ole      doordash
#
#        sub_platform   latitude   longitude country active
# 28407           NaN  43.612860 -116.352430      US   TRUE
# 30483           NaN  39.953526  -75.144688      US  FALSE
# 32915           NaN  43.607280 -116.282140      US   TRUE
# 33210           NaN  36.113230  -95.975270      US   TRUE
# 79695      doordash  38.941876  -77.076526      US   TRUE
# 117865     doordash  35.119441  -89.991273      US   TRUE
# 193039     ubereats  39.953518  -75.144657      US   TRUE
# 511555     doordash  29.424552  -98.487902      US   TRUE
# 539374     doordash  39.953526  -75.144688      US   TRUE

# %%
data[data['name'] == 'naan n curry']
# Out:
#                                restaurant_id          name      platform  \
# 11644                                  78975  naan n curry  delivery.com
# 13139                                  64978  naan n curry  delivery.com
# 14864                                  67503  naan n curry  delivery.com
# 25086                                  67756  naan n curry  delivery.com
# 43152                                  62198  naan n curry  delivery.com
# 86711                                 619452  naan n curry       grubhub
# 89006                                 206126  naan n curry       grubhub
# 145415  0dda5e2f-bad8-4ee6-a90c-a4edc3638517  naan n curry     postmates
# 164435                                414987  naan n curry       grubhub
# 210461                                548983  naan n curry       grubhub
# 364831  d87792b8-d7bd-4707-8985-abe042b817f7  naan n curry      ubereats
# 379304  18c54ba5-55d5-48b2-80e2-c92fb25db4d2  naan n curry     postmates
# 383249  13c87b71-3114-426f-a865-3a7b35a3de45  naan n curry      ubereats
# 457239                                 63240  naan n curry      doordash
#
#        sub_platform   latitude   longitude country active
# 11644           NaN  37.807229 -122.416470      US   TRUE
# 13139           NaN  37.764131 -122.464746      US   TRUE
# 14864           NaN  37.760806 -122.436675      US  FALSE
# 25086           NaN  37.867378 -122.258919      US   TRUE
# 43152           NaN  37.786156 -122.410570      US   TRUE
# 86711       grubhub  37.778570 -122.392176      US   TRUE
# 89006       grubhub  37.764119 -122.464923      US   TRUE
# 145415   restaurant  37.977136 -122.035025      US  FALSE
# 164435      grubhub  33.131191 -117.260582      US   TRUE
# 210461      grubhub  37.671795 -122.472252      US   TRUE
# 364831     ubereats  33.957845  -84.112162      US   TRUE
# 379304   restaurant  33.957821  -84.112091      US   TRUE
# 383249     ubereats  37.977136 -122.035025      US   TRUE
# 457239     doordash  37.762521 -122.419698      US   TRUE

# %% [markdown]
# It can be confirmed that the restaurants with "copy" in their names from any other platform outside of ubereats and doordash can be considered duplicate entries and can be removed from the data set.

# %%
# removing restaurants with some form of "copy" in its name & hosted on the platform delivery.com or caviar
data = data[(data['name'].str.contains('copy')) & (data['platform'] == 'delivery.com') == False]
data = data[(data['name'].str.contains('copy')) & (data['platform'] == 'caviar') == False]
print('The dataset now has {0} rows and {1} columns of restaurant data.'.format(
    data.shape[0], 
    data.shape[1])
     )
# Out:
# The dataset now has 636702 rows and 8 columns of restaurant data.

# %% [markdown]
# ##### Re-Examining Restaurants w/ Some Form of "test" in its Name

# %%
test = data[data['name'].str.contains('test')]
test
# Out:
#        restaurant_id                              name  platform sub_platform  \
# 4               5690               derek test merchant    caviar          NaN
# 878             3542  [test2]sugarfish by sushi nozawa    caviar          NaN
# 913             1183        test doc ricketts catering    caviar          NaN
# 1009            1170                 jesses test store    caviar          NaN
# 1065            2947                della test kitchen    caviar          NaN
# ...              ...                               ...       ...          ...
# 639531         50988                    dep test store  doordash     doordash
# 639594        392005            novadine v2 test store  doordash     doordash
# 639862        330076                              test  doordash     doordash
# 642231        230772         testo pepesto (e main st)  doordash     doordash
# 643046        334544                    greatest b b q  doordash     doordash
#
#          latitude   longitude country active
# 4        1.000000    2.000000      US  FALSE
# 878     40.703738  -73.638472      US  FALSE
# 913      1.000000    2.000000      US  FALSE
# 1009    37.775710 -122.418172      US  FALSE
# 1065    25.803639  -80.196274      US  FALSE
# ...           ...         ...     ...    ...
# 639531  43.638283  -79.425290      US   TRUE
# 639594  58.372186 -134.587152      US   TRUE
# 639862  33.495742  -86.876172      US   TRUE
# 642231  32.794609 -116.959992      US   TRUE
# 643046  29.592922  -95.527972      US   TRUE
#
# [447 rows x 8 columns]

# %% [markdown]
# It's again evident that whether or not the rows of data might be kept may be dependent on the platform in which that restaurant's data was found.

# %%
test['platform'].value_counts(ascending = True)
# Out:
# postmates         5
# grubhub          12
# ubereats         15
# caviar           33
# doordash        189
# delivery.com    193
# Name: platform, dtype: int64

# %% [markdown]
# I will be examining each of the rows of data on these platforms.

# %%
test[test['platform'] == 'postmates']
# Out:
#                                restaurant_id  \
# 106265  d44d89a4-4775-4537-92eb-eeb80af76638
# 142359  4d5ddf5a-3228-4905-8c87-27d14b904da1
# 351915  64b4c625-6f43-4efd-bd18-991f32654ef0
# 361862  1ebf42e8-626b-47d3-986f-654d7b8e1c50
# 424165  e59facbe-f6a6-475e-8d19-356857327868
#
#                                     name   platform sub_platform   latitude  \
# 106265          bol   test kitchen & bar  postmates   restaurant  47.676061
# 142359                    pizzeria testa  postmates   restaurant  32.830599
# 351915        project juice test kitchen  postmates   restaurant  37.777016
# 361862  testo pepesto italian restaurant  postmates   restaurant  32.794609
# 424165                della test kitchen  postmates   restaurant  25.803679
#
#          longitude country active
# 106265 -122.318264      US   TRUE
# 142359  -96.770478      US   TRUE
# 351915 -122.422349      US   TRUE
# 361862 -116.959992      US   TRUE
# 424165  -80.196424      US   TRUE

# %% [markdown]
# The text "test" appears to be part of the actual names of real restaurants. This data may be kept.

# %%
test[test['platform'] == 'grubhub']
# Out:
#        restaurant_id                              name platform sub_platform  \
# 45087         333316          dbg la test restaurant 2  grubhub      grubhub
# 55160         758384      [test] andreas slice of life  grubhub      grubhub
# 62752         308563              new whitestone diner  grubhub      grubhub
# 68488         767469                   sweetest season  grubhub      grubhub
# 71834         245945            potestas pizza & pasta  grubhub      grubhub
# 91917         275822             cascarinos whitestone  grubhub      grubhub
# 100848        536436                godiva   test test  grubhub      grubhub
# 112583        338254                    sweetest thing  grubhub      grubhub
# 180157        478947  testo pepesto italian restaurant  grubhub      grubhub
# 230573        590593                latest food trends  grubhub      grubhub
# 250149        245958      ginos of whitestone pizzeria  grubhub      grubhub
# 263132        313633            potestas pizza & pasta  grubhub      grubhub
#
#          latitude   longitude country active
# 45087   34.039689 -118.298714      US   TRUE
# 55160   41.883061  -87.631384      US   TRUE
# 62752   40.788481  -73.815340      US   TRUE
# 68488   33.415089 -111.905243      US   TRUE
# 71834   42.463948  -87.852301      US   TRUE
# 91917   40.793476  -73.809410      US   TRUE
# 100848  40.354670  -75.987996      US   TRUE
# 112583  42.117810  -76.017966      US   TRUE
# 180157  32.794609 -116.959992      US   TRUE
# 230573  40.622726  -75.481484      US   TRUE
# 250149  40.775857  -73.824429      US   TRUE
# 263132  42.352639  -87.873952      US   TRUE

# %% [markdown]
# In the grubhub restaurants with "test" in their names, we can observe that in some instances the characters in "test" may have been part of a larger word (e.g. sweetest, potestas, whitestone, testo).

# %%
test[test['platform'] == 'ubereats']
# Out:
#                                restaurant_id  \
# 100722  8da27c6a-0d8b-4c86-a6ae-f9073268a538
# 183166  78506524-4cda-46a8-ac97-ecd9a82f7e51
# 189306  12f96b7b-ad96-42a1-b440-93fd34db0c6e
# 214513  c56e6def-0372-46ea-a390-a582848fdd1a
# 246673  52b99da5-1ea4-4912-9753-15568d0d044e
# 279045  b9644439-fbf5-4280-b0a3-e5ba0e155e74
# 298572  8a94710d-fa45-4952-a988-5b4b25ebc09b
# 312009  ee30d0eb-00ad-44c9-8133-f964f99223d0
# 315708  2246e596-926e-45dc-abbb-75eb86d8a126
# 354156  2040a370-6473-4dd9-8318-9588fae4e743
# 355770  adb5e916-c389-4274-b04a-55bcdee9325a
# 373981  7ceaae79-48b1-43ad-b65a-74a2b4426aaf
# 405377  5d53613f-d349-4d84-957a-9ba856c625d1
# 407381  a01cc9cc-a650-497c-99ad-e4a67ee80271
# 420619  9d5c9e1e-f37e-4769-98d2-8ce4c887fba6
#
#                                                 name  platform sub_platform  \
# 100722                      brandons test restaurant  ubereats     ubereats
# 183166  pdq test kitchen (4343 anchor plaza parkway)  ubereats     ubereats
# 189306       panda express (401 w. whitestone blvd.)  ubereats     ubereats
# 214513                 latest food trends restaurant  ubereats     ubereats
# 246673       firehouse subs (1465 e whitestone blvd)  ubereats     ubereats
# 279045                   sweetest season bakery cafe  ubereats     ubereats
# 298572            schlotzskys (east whitestone blvd)  ubereats     ubereats
# 312009   testo pepesto italian restaurant   el cajon  ubereats     ubereats
# 315708                the village green   whitestone  ubereats     ubereats
# 354156                  patsys pizzeria   whitestone  ubereats     ubereats
# 355770             villaggio ristorante   whitestone  ubereats     ubereats
# 373981     della bowls (formerly della test kitchen)  ubereats     ubereats
# 405377                   freshii (1310 e whitestone)  ubereats     ubereats
# 407381                    nikitas place   whitestone  ubereats     ubereats
# 420619         omani korean bbq & grill   whitestone  ubereats     ubereats
#
#          latitude   longitude country active
# 100722  40.733690  -73.980203      US   TRUE
# 183166  27.981093  -82.548078      US   TRUE
# 189306  30.520203  -97.833939      US   TRUE
# 214513  40.622722  -75.481501      US   TRUE
# 246673  30.527846  -97.809447      US   TRUE
# 279045  33.415213 -111.905139      US   TRUE
# 298572  30.520558  -97.828776      US   TRUE
# 312009  32.794597 -116.959979      US   TRUE
# 315708  40.788368  -73.813389      US   TRUE
# 354156  40.777121  -73.793601      US   TRUE
# 355770  40.787697  -73.813080      US   TRUE
# 373981  25.803682  -80.196421      US   TRUE
# 405377  30.524400  -97.814500      US   TRUE
# 407381  40.780342  -73.793644      US   TRUE
# 420619  40.780561  -73.802055      US   TRUE

# %% [markdown]
# In the ubereats restaurants with "test" in their names, we can observe again that in some instances the characters in "test" may have been part of a larger word (e.g. sweetest, potestas, whitestone, testo).

# %%
test[test['platform'] == 'caviar']
# Out:
#       restaurant_id                                               name  \
# 4              5690                                derek test merchant
# 878            3542                   [test2]sugarfish by sushi nozawa
# 913            1183                         test doc ricketts catering
# 1009           1170                                  jesses test store
# 1065           2947                                 della test kitchen
# 2489           9601                     minigrow   test merchant (dne)
# 2765           4002                             colins test ristorante
# 5528           5470                                         ems   test
# 5584           1403                              test merchant chicago
# 5820           7038                         dont use  honeygrow test 2
# 6415           8200                           edwins test hrd merchant
# 6805           3867                                         test   oya
# 9680           9095                            burgerfi  test merchant
# 10704          9842  holiday test russ and daughters at the jewish ...
# 12506          2397                         project juice test kitchen
# 12549          6851                                               test
# 12974          9643                      honeygrow   test merchant dne
# 14304          7860                          blaze pizza test merchant
# 15915          1593                          shake shack test merchant
# 15973          4001                                   la test merchant
# 16697          5656                        wooster & waice [dupe test]
# 17624           571            placeholder   test only   san francisco
# 17736          8201                                 jerrys test bistro
# 19866          9689                                       test by hana
# 21131          6823                                verts test merchant
# 21229          8742                                bon me test kitchen
# 21306          1622                            placeholder   test only
# 22415          4003                               simona test merchant
# 22465          9937                             honeygrow test kitchen
# 24466          8668                       dne minigrow   test merchant
# 27629          3039                           test merchant   east bay
# 29379          7037                            dont use honeygrow test
# 30984          8260    dont use noon test merchant (verts demo vendor)
#
#       platform sub_platform    latitude   longitude country active
# 4       caviar          NaN    1.000000    2.000000      US  FALSE
# 878     caviar          NaN   40.703738  -73.638472      US  FALSE
# 913     caviar          NaN    1.000000    2.000000      US  FALSE
# 1009    caviar          NaN   37.775710 -122.418172      US  FALSE
# 1065    caviar          NaN   25.803639  -80.196274      US  FALSE
# 2489    caviar          NaN   40.751731  -73.979705      US  FALSE
# 2765    caviar          NaN   37.775232  122.419717      US  FALSE
# 5528    caviar          NaN   32.779322  -96.828607      US  FALSE
# 5584    caviar          NaN   41.974162  -87.907321      US  FALSE
# 5820    caviar          NaN   41.885252  -87.652084      US  FALSE
# 6415    caviar          NaN   37.799553 -122.407773      US  FALSE
# 6805    caviar          NaN   38.894971  -77.021721      US  FALSE
# 9680    caviar          NaN   37.775316 -122.417437      US  FALSE
# 10704   caviar          NaN   40.785421  -73.957293      US  FALSE
# 12506   caviar          NaN   37.777114 -122.422392      US   TRUE
# 12549   caviar          NaN   37.775231 -122.417557      US  FALSE
# 12974   caviar          NaN   39.953810  -75.197886      US  FALSE
# 14304   caviar          NaN  555.000000  555.000000      US  FALSE
# 15915   caviar          NaN   40.740876  -73.987981      US  FALSE
# 15973   caviar          NaN   34.151359 -118.254615      US  FALSE
# 16697   caviar          NaN   40.109301   85.741314      US  FALSE
# 17624   caviar          NaN  231.423200 -122.392876      US  FALSE
# 17736   caviar          NaN   37.785987 -122.421174      US  FALSE
# 19866   caviar          NaN    1.000000    1.000000      US  FALSE
# 21131   caviar          NaN   37.775231 -122.417528      US  FALSE
# 21229   caviar          NaN   42.365026  -71.079815      US  FALSE
# 21306   caviar          NaN   37.784069 -122.417594      US  FALSE
# 22415   caviar          NaN   40.604945  -73.979885      US  FALSE
# 22465   caviar          NaN   39.974462  -75.134490      US  FALSE
# 24466   caviar          NaN   41.881234  -87.626756      US  FALSE
# 27629   caviar          NaN   37.814322 -122.246585      US  FALSE
# 29379   caviar          NaN   42.344448  -71.096996      US  FALSE
# 30984   caviar          NaN   37.775231 -122.417528      US  FALSE

# %% [markdown]
# In the caviar restaurants with "test" in their names, we can almost every single row suggests that the data is some sort of duplicate. However, there are rare instances where the row of data, while still capable of being a duplicate, may hold valuable information for real restaurants.

# %%
test[test['platform'] == 'doordash']
# Out:
#        restaurant_id                       name  platform sub_platform  \
# 46765         421761       red robin test store  doordash     doordash
# 49118         385736     burger king test store  doordash     doordash
# 49121         387045           aloha test store  doordash     doordash
# 49514         175322        brians test kitchen  doordash     doordash
# 52546          50769    baskin robbins (tester)  doordash     doordash
# ...              ...                        ...       ...          ...
# 639531         50988             dep test store  doordash     doordash
# 639594        392005     novadine v2 test store  doordash     doordash
# 639862        330076                       test  doordash     doordash
# 642231        230772  testo pepesto (e main st)  doordash     doordash
# 643046        334544             greatest b b q  doordash     doordash
#
#          latitude   longitude country active
# 46765   58.372194 -134.590883      US  FALSE
# 49118   58.371417 -134.589679      US  FALSE
# 49121   58.371404 -134.589536      US  FALSE
# 49514   41.170561  -71.557459      US  FALSE
# 52546   43.628429  -79.413533      US  FALSE
# ...           ...         ...     ...    ...
# 639531  43.638283  -79.425290      US   TRUE
# 639594  58.372186 -134.587152      US   TRUE
# 639862  33.495742  -86.876172      US   TRUE
# 642231  32.794609 -116.959992      US   TRUE
# 643046  29.592922  -95.527972      US   TRUE
#
# [189 rows x 8 columns]

# %% [markdown]
# In the doordash restaurants with "test" in their names, we can almost every single row suggests that the data is some sort of duplicate. However, again there are rare instances where the row of data, while still capable of being a duplicate, may hold valuable information for real restaurants.
#
# At this stage it is becoming apparent that I need to refine the regex filter for the characters in "test" to exclude the use of said characters in larger words.

# %%
test[test['platform'] == 'delivery.com']
# Out:
#       restaurant_id                                             name  \
# 1234          73943                                             test
# 1629          64841  fake restaurnt for ernestine test new menu tool
# 1719          73777                                     menu test 67
# 1732          87341                               johns pizza   test
# 1864          91972                             chowly test merchant
# ...             ...                                              ...
# 43622         71684                          testing merchant 121212
# 43867         30541    zzz test merchant    dg   new data entry tool
# 44144         64489                               hale & hearty test
# 44625         62179                                             test
# 44742         87883                            dc taxi test merchant
#
#            platform sub_platform   latitude  longitude country active
# 1234   delivery.com          NaN  40.726933 -73.235764      US   TRUE
# 1629   delivery.com          NaN  40.737710 -73.987949      US  FALSE
# 1719   delivery.com          NaN  40.839090 -74.282754      US   TRUE
# 1732   delivery.com          NaN  40.751824 -73.986455      US   TRUE
# 1864   delivery.com          NaN  40.746854 -73.997194      US   TRUE
# ...             ...          ...        ...        ...     ...    ...
# 43622  delivery.com          NaN  40.740615 -73.888321      US   TRUE
# 43867  delivery.com          NaN  40.762646 -73.969185      US  FALSE
# 44144  delivery.com          NaN  41.714577 -83.684994      US   TRUE
# 44625  delivery.com          NaN  39.961041 -75.194753      US   TRUE
# 44742  delivery.com          NaN  38.902520 -77.030790      US   TRUE
#
# [193 rows x 8 columns]

# %% [markdown]
# In the delivery.com restaurants with "test" in their names, we can almost every single row suggests that the data is some sort of duplicate. However, again there are rare instances where the row of data, while still capable of being a duplicate, may hold valuable information for real restaurants.

# %%
sketchy_test_data = (test[test['platform'] == 'caviar'].shape[0] + test[test['platform'] == 'doordash'].shape[0] + test[test['platform'] == 'delivery.com'].shape[0]) / data.shape[0] * 100
print(round(sketchy_test_data, 3), '% of the dataset')
# Out:
# 0.065 % of the dataset

# %% [markdown]
# Given the time constraints given to complete this assignment, instead of using more complex regex to distinguish between rows with the characters "test" in restaurant names, I will instead only keep the rows in which the platform was either postmates, grubhub, or ubereats.
#
# Upon observation, the other platforms (caviar, doordash, delivery.com) were almost entirely duplicate rows of data. Even if all of these questionable rows of data were real restaurants and not duplicates, they make up just 0.038% of the dataset and are almost inconsequential to the final results.

# %%
# removing restaurants with some form of "test" in its name & hosted on the platforms caviar, doordash, or delivery.com
data = data[(data['name'].str.contains('test')) & (data['platform'] == 'caviar') == False]
data = data[(data['name'].str.contains('test')) & (data['platform'] == 'doordash') == False]
data = data[(data['name'].str.contains('test')) & (data['platform'] == 'delivery.com') == False]
print('The dataset now has {0} rows and {1} columns of restaurant data.'.format(
    data.shape[0], 
    data.shape[1])
     )
# Out:
# The dataset now has 636287 rows and 8 columns of restaurant data.

# %% [markdown]
# #### Revisiting Strange Coordinate Data
#
# As a reminder, according to the information found at this [link](https://latitudelongitude.org/us/), the range of latitude and longitude values for US cities should range from:
# - Latitude: 19.50139 to 64.85694
# - Longitude: -161.75583 to -68.01197
#
# I am also using this website to quickly check my logic when appropriate with regards to the location of restaurants.

# %% [markdown]
# #### Strange Latitude Values

# %%
data[data['latitude'] < 15]
# Out:
#       restaurant_id                                      name  platform  \
# 166            9812  the french bakery   112th ave [disabled]    caviar
# 907            9607                        [dnu] toms dim sum    caviar
# 1461          10348                          pho viet 11th st    caviar
# 2430           7415                                pappasitos    caviar
# 2819          10316                       norah restaurant la    caviar
# 5596          10335                    india palace   alameda    caviar
# 6772          10365                                holy cluck    caviar
# 6995          10155                      tangs pacific bistro    caviar
# 8918          10176      smoke daddy bbq   wrigleyville   dnu    caviar
# 8928          10337                 flacos tacos   south loop    caviar
# 9092          10345             galveston restaurant and cafe    caviar
# 10272         10363                    takorean catering   dc    caviar
# 10365         10347                              pinkys pizza    caviar
# 10635         10353                     hax hops & hamburgers    caviar
# 10709         10346                                 tasty bbq    caviar
# 12390         10334                                   hala in    caviar
# 12469         10336                                  bonafini    caviar
# 14300         10333                                 bixi beer    caviar
# 14319          4077                                       olo    caviar
# 16197         10359                                     i tea    caviar
# 16217         10366                             sons addition    caviar
# 16220         10358                               tsuki sushi    caviar
# 16704         10324                                 hamiltons    caviar
# 17484         10356                              destroyer la    caviar
# 19892          9813    the french bakery   8th st. [disabled]    caviar
# 20181         10357                 norah restaurant la   dnu    caviar
# 21274         10349                             psychic wines    caviar
# 23839         10362                             leaning tower    caviar
# 24505         10344                            brotzeit lokal    caviar
# 28976         10364                          stonemill matcha    caviar
# 29388         10360                                     bhuna    caviar
# 29391         10354                            camperdown elm    caviar
# 29776         10355           wok wok southeast asian kitchen    caviar
# 30276         10223                                  republic    caviar
# 46620         45735                                 mod pizza  doordash
#
#       sub_platform   latitude   longitude country active
# 166            NaN   1.000000   -1.000000      US  FALSE
# 907            NaN  11.000000  -11.000000      US  FALSE
# 1461           NaN   1.000000    1.000000      US  FALSE
# 2430           NaN   0.111111    0.111111      US  FALSE
# 2819           NaN   1.000000    1.000000      US  FALSE
# 5596           NaN   1.000000    1.000000      US  FALSE
# 6772           NaN   1.000000    1.000000      US  FALSE
# 6995           NaN  11.000000  -11.000000      US  FALSE
# 8918           NaN   1.000000    1.000000      US  FALSE
# 8928           NaN   1.000000    1.000000      US  FALSE
# 9092           NaN   1.000000    1.000000      US  FALSE
# 10272          NaN   1.000000    1.000000      US  FALSE
# 10365          NaN   1.000000   -1.000000      US  FALSE
# 10635          NaN   1.000000    1.000000      US  FALSE
# 10709          NaN   1.000000   -1.000000      US  FALSE
# 12390          NaN   1.000000    1.000000      US  FALSE
# 12469          NaN   1.000000    1.000000      US  FALSE
# 14300          NaN   1.000000    1.000000      US  FALSE
# 14319          NaN   1.000000    1.000000      US  FALSE
# 16197          NaN   1.000000   -1.000000      US  FALSE
# 16217          NaN   1.000000    1.000000      US  FALSE
# 16220          NaN   1.000000   -1.000000      US  FALSE
# 16704          NaN   1.000000    1.000000      US  FALSE
# 17484          NaN   1.000000    1.000000      US  FALSE
# 19892          NaN   1.000000   -1.000000      US  FALSE
# 20181          NaN   1.000000    1.000000      US  FALSE
# 21274          NaN   1.000000    1.000000      US  FALSE
# 23839          NaN   1.000000    1.000000      US  FALSE
# 24505          NaN   1.000000    1.000000      US  FALSE
# 28976          NaN   1.000000    1.000000      US  FALSE
# 29388          NaN   1.000000   -1.000000      US  FALSE
# 29391          NaN   1.000000    1.000000      US  FALSE
# 29776          NaN   1.000000    1.000000      US  FALSE
# 30276          NaN  11.000000  -11.000000      US  FALSE
# 46620     doordash  14.215883  121.141894      US  FALSE

# %% [markdown]
# After lengthy cleaning of the data, just a handful of rows of data remain that have questionable latitude values. Almost all of the values above have an observable pattern:
# - The platform this restaurant data was taken from was caviar
# - The coordinate values are just some form of the number 1 for both latitude and longitude
# - The restaurant is listed as inactive
#
# The sole exception is the restaurant "mod pizza", but given its inactive status and the fact that the coordinates place the restaurant somewhere hundreds of miles below the US, I feel confident in just removing this from the dataset.
#
# Also something to note is that there are two observable rows in which "dnu" and "disabled" are mentioned in the restaurant names. More on this later.

# %%
data[data['latitude'] > 70]
# Out:
#       restaurant_id                    name platform sub_platform  latitude  \
# 602            8869  mi joe chinese cuisine   caviar          NaN     111.0
# 12497          6426         (reuse cms id.)   caviar          NaN     123.0
#
#        longitude country active
# 602       -111.0      US  FALSE
# 12497      456.0      US  FALSE

# %% [markdown]
# Only two rows of data contain restaurants in which the latitude is listed as greater than 70. Both of these rows hold questionable data, as the coordinates are listed as 111, -111 and 123, 456. These will be removed from the dataset.

# %%
# removing illogical latitude values from our dataset
data = data[data['latitude'] <= 70]
data = data[data['latitude'] >= 15]
print('The dataset now has {0} rows and {1} columns of restaurant data.'.format(
    data.shape[0], 
    data.shape[1])
     )
# Out:
# The dataset now has 636250 rows and 8 columns of restaurant data.

# %% [markdown]
# #### Strange Longitude Values

# %%
data[data['longitude'] < -165]
# Out:
# Empty DataFrame
# Columns: [restaurant_id, name, platform, sub_platform, latitude, longitude, country, active]
# Index: []

# %% [markdown]
# There are no more outstanding longitude values in which the stated longitude is lower than the expected range of -161.75583 to -68.01197.

# %%
data[data['longitude'] > -60]
# Out:
#        restaurant_id                                name  platform  \
# 2677            1624           cms certification [wendy]    caviar
# 6462            9300           nekter juice bar pasadena    caviar
# 6467             769               southland flavor cafe    caviar
# 8728            3409          belcampo at the yard [dnu]    caviar
# 16037           5473           naansense   east lakeview    caviar
# 27002           9323      nekter juice bar  santa monica    caviar
# 27006            443                             fred 62    caviar
# 46472          51173                        swiss chalet  doordash
# 49305          16960                        taco sinaloa  doordash
# 49337          16863               island eats hale aina  doordash
# 52507          15704                           swan thai  doordash
# 60135          16961              eddie vs prime seafood  doordash
# 61209          51114         five guys burgers and fries  doordash
# 63180         130021                         osaka japan  doordash
# 63286          15685        soho thai fusion bar & grill  doordash
# 66441          38059                      fish & camaron  doordash
# 66568          15064          panda express (s figueroa)  doordash
# 69564          14335                          love sushi  doordash
# 71924          15451                einstein bros bagels  doordash
# 73315          19011                   simply fish grill  doordash
# 73387          12253          heat 7 indian asian bistro  doordash
# 74311         425079            rockys hot chicken shack  doordash
# 77776          61958                 pei wei asian diner  doordash
# 80393         397598  subway�� restaurant (james street)  doordash
# 81721          19044                      mandarin lotus  doordash
# 82359          16892                        tapas & vino  doordash
# 84011          16727            redondo beach brewing co  doordash
# 84227          19060                         p&l burgers  doordash
# 84274          19008         petra mediterranean cuisine  doordash
# 84486          15078          the coffee bean & tea leaf  doordash
# 86960         129958             cafe bistro (nordstrom)  doordash
# 87065          16883                          ocean tava  doordash
# 87594          21033            jongewaards bake n broil  doordash
# 88620          12055           dana kai japanese cuisine  doordash
# 91007          63245                     hey thats amore  doordash
# 98600          16889             patra burgers on sunset  doordash
# 99822         131644                             chen fu  doordash
# 101384        153676                       panda express  doordash
# 101743         15878                          tulip cafe  doordash
# 101860         15597                       the blue star  doordash
# 102284         11142                                 cvs  doordash
# 108881        153854                              sbarro  doordash
# 109287         19295                            cortinas  doordash
# 110065         65056                 el charro taco shop  doordash
# 110180        130073         hot dog on a stick (murray)  doordash
#
#        sub_platform   latitude   longitude country active
# 2677            NaN  37.775505  122.418193      US  FALSE
# 6462            NaN  34.139870  118.132678      US  FALSE
# 6467            NaN  37.335545   37.335545      US  FALSE
# 8728            NaN  19.994719   -9.996014      US  FALSE
# 16037           NaN  41.943001   41.943001      US  FALSE
# 27002           NaN  34.014169  118.496774      US  FALSE
# 27006           NaN  34.104648  118.291491      US  FALSE
# 46472      doordash  43.730189   43.730189      US  FALSE
# 49305      doordash  33.831760  118.308240      US  FALSE
# 49337      doordash  33.857330  118.299230      US  FALSE
# 52507      doordash  33.748590  118.406970      US  FALSE
# 60135      doordash  32.818073   96.802686      US  FALSE
# 61209      doordash  43.619486   43.619486      US  FALSE
# 63180      doordash  40.643485  111.889372      US  FALSE
# 63286      doordash  33.789260  118.317500      US  FALSE
# 66441      doordash  30.191721   95.585515      US  FALSE
# 66568      doordash  34.025876  118.277276      US  FALSE
# 69564      doordash  33.181043   96.884608      US  FALSE
# 71924      doordash  34.062088  118.350072      US  FALSE
# 73315      doordash  34.153560  118.757380      US  FALSE
# 73387      doordash  34.156900  118.484200      US  FALSE
# 74311      doordash  28.668361   77.951021      US  FALSE
# 77776      doordash  30.235956   97.733920      US  FALSE
# 80393      doordash  53.802131   -9.514347      US  FALSE
# 81721      doordash  34.144440  118.761530      US  FALSE
# 82359      doordash  33.817440  118.388090      US  FALSE
# 84011      doordash  33.816940  118.387090      US  FALSE
# 84227      doordash  34.210800  118.842100      US  FALSE
# 84274      doordash  34.163750  118.828020      US  FALSE
# 84486      doordash  34.074048  118.323864      US  FALSE
# 86960      doordash  40.643485  111.889372      US  FALSE
# 87065      doordash  33.823830  118.385140      US  FALSE
# 87594      doordash  33.824070   33.824070      US  FALSE
# 88620      doordash  33.488690  117.710070      US  FALSE
# 91007      doordash  34.147830  118.149870      US  FALSE
# 98600      doordash  34.076000  118.256130      US  FALSE
# 99822      doordash  35.135700   80.712630      US  FALSE
# 101384     doordash  40.643485  111.889372      US  FALSE
# 101743     doordash  34.045970  118.253540      US  FALSE
# 101860     doordash  34.021740  118.232640      US  FALSE
# 102284     doordash  33.996326   33.996326      US  FALSE
# 108881     doordash  40.643485  111.889372      US  FALSE
# 109287     doordash  33.825350   33.825350      US  FALSE
# 110065     doordash  33.966510  118.115860      US  FALSE
# 110180     doordash  40.643485  111.889372      US  FALSE

# %% [markdown]
# Although just a few, there are some strange longitudes stated in which the longitude values are greater than -70. This could be for a variety of reasons, such as:
# - The data is indeed supposed to be removed from the dataset
#     - Some additional tags added to the names of some our datasets can be seen above (e.g. dnu, disabled)
# - The data may simply have been incorrectly input
#     - e.g. The restaurant listed at index 2677 is found in the middle of the Yellow Sea based on the given coordinates, but by making the longitude value (-) the coordinates then place the restaurant in San Francisco. That probably makes more sense than a restaurant floating in the middle of a large body of water.
#
# Note: Some of these restaurant coordinates above are not accurately represented as some coordinates place the restaurant outside of the US or have the exact same latitude value as longitude value (highly unlikely). However, accomplishing the goal of getting rid of duplicates doesn't mean I should get rid of a restaurant solely on the observation that the data was input and/or collected incorrectly.

# %%
# transforming all longitude values to negatives
data['longitude'] = data['longitude'].apply(lambda x: x * -1 if x > 0 else x)

# %%
data[data['longitude'] > -60]
# Out:
#        restaurant_id                                name  platform  \
# 6467             769               southland flavor cafe    caviar
# 8728            3409          belcampo at the yard [dnu]    caviar
# 16037           5473           naansense   east lakeview    caviar
# 46472          51173                        swiss chalet  doordash
# 61209          51114         five guys burgers and fries  doordash
# 80393         397598  subway�� restaurant (james street)  doordash
# 87594          21033            jongewaards bake n broil  doordash
# 102284         11142                                 cvs  doordash
# 109287         19295                            cortinas  doordash
#
#        sub_platform   latitude  longitude country active
# 6467            NaN  37.335545 -37.335545      US  FALSE
# 8728            NaN  19.994719  -9.996014      US  FALSE
# 16037           NaN  41.943001 -41.943001      US  FALSE
# 46472      doordash  43.730189 -43.730189      US  FALSE
# 61209      doordash  43.619486 -43.619486      US  FALSE
# 80393      doordash  53.802131  -9.514347      US  FALSE
# 87594      doordash  33.824070 -33.824070      US  FALSE
# 102284     doordash  33.996326 -33.996326      US  FALSE
# 109287     doordash  33.825350 -33.825350      US  FALSE

# %% [markdown]
# With the exception of a few rows, the only remaining rows with illogical longitude data are those that appear to have incorrectly assigned longitude values that were the exact same as the latitude values before the values were transformed into negative values.

# %% [markdown]
# #### A Final Glance at Restaurant Names

# %% [markdown]
# As mentioned earlier, I observed a restaurant with "dnu" in its name, which based on previously observed data most likely is an acronym standing for "do not use". I also observed a restaurant with "disabled" in its name. I will once more run over the data set and remove anything with "dnu" or "disabled".

# %% [markdown]
# ##### Names w/"Disabled"

# %%
disabled_data = data[data['name'].str.contains('disable')]
disabled_data
# Out:
#       restaurant_id                              name platform sub_platform  \
# 188            6663         [disabled] little toasted   caviar          NaN
# 410            8936       prime cookie co. [disabled]   caviar          NaN
# 494             215       (perm disabled) maiden lane   caviar          NaN
# 502             254                   penang disabled   caviar          NaN
# 557            3829           [disabled] kelloggs nyc   caviar          NaN
# ...             ...                               ...      ...          ...
# 30603          7203  [disabled] aybla grill   divison   caviar          NaN
# 30894          7236        [disabled] little taqueria   caviar          NaN
# 30978          6171                    [disabled] mau   caviar          NaN
# 30997          6488   (disabled) chimney coffee house   caviar          NaN
# 31020          2669                  [disabled] roses   caviar          NaN
#
#         latitude   longitude country active
# 188    41.877650  -87.638630      US  FALSE
# 410    32.794389  -96.800166      US  FALSE
# 494    40.727128  -73.979851      US  FALSE
# 502    42.351373  -71.063005      US  FALSE
# 557    40.760178  -73.984305      US  FALSE
# ...          ...         ...     ...    ...
# 30603  45.504940 -122.634551      US  FALSE
# 30894  37.784642 -122.464404      US  FALSE
# 30978  37.762219 -122.421446      US  FALSE
# 30997  34.063084 -118.232475      US  FALSE
# 31020  40.678979  -73.973429      US  FALSE
#
# [115 rows x 8 columns]

# %%
disabled_data['platform'].value_counts(ascending = False)
# Out:
# caviar    115
# Name: platform, dtype: int64

# %% [markdown]
# There are over one hundred rows of data in which the restaurant is labeled "disabled". I suspected that most, if not all, of these rows belonged to the caviar platform due to observed tendencies in the dataset earlier. My suspicion was correct, and I will proceed to remove all of the instances in which "disabled" is a part of the name of the restaurant.

# %%
# removing restaurants with some form of "disable" in its name
data = data[data['name'].str.contains('disable') == False]
print('The dataset now has {0} rows and {1} columns of restaurant data.'.format(
    data.shape[0], 
    data.shape[1])
     )
# Out:
# The dataset now has 636135 rows and 8 columns of restaurant data.

# %% [markdown]
# ##### Names w/ "dnu"

# %%
dnu_data = data[data['name'].str.contains('dnu')]
dnu_data
# Out:
#        restaurant_id                              name  platform sub_platform  \
# 309             8570                       arami   dnu    caviar          NaN
# 1556            6294   [dnu] the little beet menu bank    caviar          NaN
# 2639             224       la sirena clandestina   dnu    caviar          NaN
# 2643            9629  [dnu]takumen izakaya and noodles    caviar          NaN
# 2694            9692                       dnu (trash)    caviar          NaN
# ...              ...                               ...       ...          ...
# 633259        415446                           podnuhs  doordash     doordash
# 640660        415452                   podnuhs bar b q  doordash     doordash
# 642842        415430                   podnuhs bar b q  doordash     doordash
# 642851        415459                       podnuhs bbq  doordash     doordash
# 642858        415433                   podnuhs bar b q  doordash     doordash
#
#          latitude  longitude country active
# 309     41.895750 -87.673312      US  FALSE
# 1556    40.757672 -73.974219      US  FALSE
# 2639    41.886987 -87.651970      US  FALSE
# 2643    40.742594 -73.954678      US  FALSE
# 2694    32.896067 -96.802133      US  FALSE
# ...           ...        ...     ...    ...
# 633259  32.409714 -93.797917      US   TRUE
# 640660  32.486804 -93.707380      US   TRUE
# 642842  32.545441 -93.777455      US   TRUE
# 642851  32.433664 -93.712221      US   TRUE
# 642858  32.516521 -93.716983      US   TRUE
#
# [87 rows x 8 columns]

# %%
dnu_data['platform'].value_counts(ascending = True)
# Out:
# postmates     1
# ubereats      2
# grubhub       2
# doordash     19
# caviar       63
# Name: platform, dtype: int64

# %% [markdown]
# I will observe the values by each platform once again.

# %%
dnu_data[dnu_data['platform'] == 'postmates']
# Out:
#                                restaurant_id             name   platform  \
# 397238  ac64895d-d262-4cf5-8244-a699f1980af4  spudnuts donuts  postmates
#
#        sub_platform   latitude   longitude country active
# 397238   restaurant  34.219232 -118.606498      US   TRUE

# %%
dnu_data[dnu_data['platform'] == 'grubhub']
# Out:
#        restaurant_id                       name platform sub_platform  \
# 51225         697334            spudnuts donuts  grubhub      grubhub
# 132278        337448  art of donuts by spudnuts  grubhub      grubhub
#
#          latitude   longitude country active
# 51225   34.176361 -118.946053      US   TRUE
# 132278  34.219181 -118.606526      US   TRUE

# %%
dnu_data[dnu_data['platform'] == 'ubereats']
# Out:
#                                restaurant_id                             name  \
# 169106  5c27f474-ea4b-4ee1-ad3f-fa3b183b0bde                  spudnuts donuts
# 169795  ea896f44-b029-4cbe-9c1e-84b2abc5b0a2  spudnuts donuts (thousand oaks)
#
#         platform sub_platform   latitude   longitude country active
# 169106  ubereats     ubereats  34.219181 -118.606526      US   TRUE
# 169795  ubereats     ubereats  34.176361 -118.946054      US   TRUE

# %%
dnu_data[dnu_data['platform'] == 'doordash']
# Out:
#        restaurant_id                         name  platform sub_platform  \
# 297165        324441              podnuhs bar b q  doordash     doordash
# 312641        324448              podnuhs bar b q  doordash     doordash
# 472869        275211              spudnuts donuts  doordash     doordash
# 475255        353628            spudnut doughnuts  doordash     doordash
# 492151        343349            spudnuts & bagels  doordash     doordash
# 497584        275192              spudnuts donuts  doordash     doordash
# 497585        275203              spudnuts donuts  doordash     doordash
# 498421        261327                     spudnuts  doordash     doordash
# 504492        353629              spudnuts donuts  doordash     doordash
# 528736        335603                        dnuez  doordash     doordash
# 529482        229443           johnny os spudnuts  doordash     doordash
# 541454        242989  spudnuts donuts (kimber dr)  doordash     doordash
# 597514        242902              spudnuts donuts  doordash     doordash
# 603273        359560                   coco dnuts  doordash     doordash
# 633259        415446                      podnuhs  doordash     doordash
# 640660        415452              podnuhs bar b q  doordash     doordash
# 642842        415430              podnuhs bar b q  doordash     doordash
# 642851        415459                  podnuhs bbq  doordash     doordash
# 642858        415433              podnuhs bar b q  doordash     doordash
#
#          latitude   longitude country active
# 297165  30.427057  -91.055749      US   TRUE
# 312641  30.450961  -91.117869      US   TRUE
# 472869  34.412034 -119.854841      US   TRUE
# 475255  34.272667 -119.213847      US   TRUE
# 492151  34.440194 -119.741430      US   TRUE
# 497584  34.435949 -119.823791      US   TRUE
# 497585  34.419084 -119.704980      US   TRUE
# 498421  34.172656 -119.161177      US   TRUE
# 504492  34.175490 -119.221885      US   TRUE
# 528736  41.857811  -87.676162      US   TRUE
# 529482  41.091404 -111.974113      US   TRUE
# 541454  34.176411 -118.945829      US   TRUE
# 597514  34.219199 -118.606654      US   TRUE
# 603273  34.200792 -118.527732      US   TRUE
# 633259  32.409714  -93.797917      US   TRUE
# 640660  32.486804  -93.707380      US   TRUE
# 642842  32.545441  -93.777455      US   TRUE
# 642851  32.433664  -93.712221      US   TRUE
# 642858  32.516521  -93.716983      US   TRUE

# %%
dnu_data[dnu_data['platform'] == 'caviar']
# Out:
#       restaurant_id                               name platform sub_platform  \
# 309            8570                        arami   dnu   caviar          NaN
# 1556           6294    [dnu] the little beet menu bank   caviar          NaN
# 2639            224        la sirena clandestina   dnu   caviar          NaN
# 2643           9629   [dnu]takumen izakaya and noodles   caviar          NaN
# 2694           9692                        dnu (trash)   caviar          NaN
# ...             ...                                ...      ...          ...
# 26963          2442  dnu california pizza kitchen   sf   caviar          NaN
# 27025          1607                    the allis   dnu   caviar          NaN
# 28687          9193     urbanbelly   wicker park   dnu   caviar          NaN
# 28945          4948          armands victory tap   dnu   caviar          NaN
# 30589          5876           dnu bareburger   chelsea   caviar          NaN
#
#         latitude   longitude country active
# 309    41.895750  -87.673312      US  FALSE
# 1556   40.757672  -73.974219      US  FALSE
# 2639   41.886987  -87.651970      US  FALSE
# 2643   40.742594  -73.954678      US  FALSE
# 2694   32.896067  -96.802133      US  FALSE
# ...          ...         ...     ...    ...
# 26963  37.786788 -122.402693      US  FALSE
# 27025  41.883746  -87.648281      US  FALSE
# 28687  41.909663  -87.677839      US  FALSE
# 28945  41.863503  -87.624538      US  FALSE
# 30589  40.742106  -74.001160      US  FALSE
#
# [63 rows x 8 columns]

# %% [markdown]
# Again, it is only the data on the platform caviar that seems to add the characters "dnu" as a label/tag as opposed to those characters being a part of the name of the restaurant itself (e.g. "spudnuts donuts"). I will remove rows of data with "dnu" in the name from the dataset if the platform is caviar.

# %%
# removing restaurants with some form of "dnu" in its name & hosted on the platform caviar
data = data[(data['name'].str.contains('dnu')) & (data['platform'] == 'caviar') == False]
print('The dataset now has {0} rows and {1} columns of restaurant data.'.format(
    data.shape[0], 
    data.shape[1])
     )
# Out:
# The dataset now has 636072 rows and 8 columns of restaurant data.

# %% [markdown]
# #### Checking Active vs. Inactive

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 636072 entries, 0 to 644069
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   restaurant_id  636072 non-null  object
#  1   name           636072 non-null  object
#  2   platform       636072 non-null  object
#  3   sub_platform   593950 non-null  object
#  4   latitude       636072 non-null  float64
#  5   longitude      636072 non-null  float64
#  6   country        636072 non-null  object
#  7   active         635876 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 43.7+ MB

# %%
null_active = data[data['active'].isnull()]
null_active
# Out:
#                                restaurant_id  \
# 96548   2783a54d-8014-46c1-b854-483964ef8605
# 96957   c02d95df-cfd3-44d6-b511-7025df9b4cc6
# 97840   0ece7f40-b225-4050-a075-4e677cc7cdf3
# 104011  cfa89126-1522-46cf-af7a-37ab6dde4595
# 104301  dd5b41fe-6bab-4bb0-a156-3e6c85766cd6
# ...                                      ...
# 426412  5602435b-bb43-4a4d-adf1-b452eaecbaa4
# 428301  300c5357-6d7f-4931-9f74-d7f756965d4a
# 431378  3dc72f79-f55b-4cd5-9c82-d7ce453682c5
# 433562  a68318d7-e038-476e-9af8-38d7c2b446f4
# 440642  177e25d8-9514-448c-aa6c-bd46252c5d3b
#
#                                             name   platform sub_platform  \
# 96548                                  fish dish  postmates   restaurant
# 96957                                 waba grill  postmates   restaurant
# 97840                                   woodland  postmates   restaurant
# 104011                                leaf & co.  postmates   restaurant
# 104301                       the late night spot  postmates   restaurant
# ...                                          ...        ...          ...
# 426412  grasslands meat market | bbq & churrasco  postmates   restaurant
# 428301                      frank & finas cocina  postmates   restaurant
# 431378                              asian bistro  postmates   restaurant
# 433562                          la buca di marco  postmates   restaurant
# 440642                          l&l hawaiian bbq  postmates   restaurant
#
#          latitude   longitude country active
# 96548   34.195293 -118.350281      US    NaN
# 96957   34.223720 -118.502206      US    NaN
# 97840   40.680174  -73.974945      US    NaN
# 104011  30.015423  -90.239225      US    NaN
# 104301  36.100607 -115.133308      US    NaN
# ...           ...         ...     ...    ...
# 426412  33.805773 -117.911407      US    NaN
# 428301  36.113486 -115.307372      US    NaN
# 431378  19.348821  -99.189638      US    NaN
# 433562  39.292775  -76.587802      US    NaN
# 440642  33.657061 -117.916856      US    NaN
#
# [196 rows x 8 columns]

# %%
null_active['platform'].value_counts()
# Out:
# postmates    195
# ubereats       1
# Name: platform, dtype: int64

# %% [markdown]
# Almost all of the NaN values in the dataset correspond to restaurants from the platform postmates. One row of data with NaN for the active value is from the platform ubereats.

# %% [markdown]
# #### Addressing Active/Inactive for Postmates Data

# %%
postmates_data = data[data['platform'] == 'postmates']
print(postmates_data.shape[0], 'restaurants on postmates from the dataset')
print('\n')
print(postmates_data['active'].value_counts(dropna = True, normalize = True) * 100)
# Out:
# 110237 restaurants on postmates from the dataset
#
#
# TRUE     67.929518
# FALSE    32.070482
# Name: active, dtype: float64

# %% [markdown]
# The majority (67.93%) of the 110,237 restaurants on the postmates platform are listed as active in our dataset. Because a majority is listed as active, my time-sensitive solution for the rows in which the platform is postmates and the active column is NaN is to change NaN to "TRUE".

# %%
data[(data['platform'] == 'postmates') & (data['active'].isnull())]
# Out:
#                                restaurant_id  \
# 96548   2783a54d-8014-46c1-b854-483964ef8605
# 96957   c02d95df-cfd3-44d6-b511-7025df9b4cc6
# 97840   0ece7f40-b225-4050-a075-4e677cc7cdf3
# 104011  cfa89126-1522-46cf-af7a-37ab6dde4595
# 104301  dd5b41fe-6bab-4bb0-a156-3e6c85766cd6
# ...                                      ...
# 426412  5602435b-bb43-4a4d-adf1-b452eaecbaa4
# 428301  300c5357-6d7f-4931-9f74-d7f756965d4a
# 431378  3dc72f79-f55b-4cd5-9c82-d7ce453682c5
# 433562  a68318d7-e038-476e-9af8-38d7c2b446f4
# 440642  177e25d8-9514-448c-aa6c-bd46252c5d3b
#
#                                             name   platform sub_platform  \
# 96548                                  fish dish  postmates   restaurant
# 96957                                 waba grill  postmates   restaurant
# 97840                                   woodland  postmates   restaurant
# 104011                                leaf & co.  postmates   restaurant
# 104301                       the late night spot  postmates   restaurant
# ...                                          ...        ...          ...
# 426412  grasslands meat market | bbq & churrasco  postmates   restaurant
# 428301                      frank & finas cocina  postmates   restaurant
# 431378                              asian bistro  postmates   restaurant
# 433562                          la buca di marco  postmates   restaurant
# 440642                          l&l hawaiian bbq  postmates   restaurant
#
#          latitude   longitude country active
# 96548   34.195293 -118.350281      US    NaN
# 96957   34.223720 -118.502206      US    NaN
# 97840   40.680174  -73.974945      US    NaN
# 104011  30.015423  -90.239225      US    NaN
# 104301  36.100607 -115.133308      US    NaN
# ...           ...         ...     ...    ...
# 426412  33.805773 -117.911407      US    NaN
# 428301  36.113486 -115.307372      US    NaN
# 431378  19.348821  -99.189638      US    NaN
# 433562  39.292775  -76.587802      US    NaN
# 440642  33.657061 -117.916856      US    NaN
#
# [195 rows x 8 columns]

# %% [markdown]
# #### Addressing Active/Inactive for Ubereats Data

# %%
null_active[null_active['platform'] == 'ubereats']
# Out:
#                                restaurant_id  \
# 349951  70af6b2e-37d6-4ece-b5f3-ec9d03533b4c
#
#                                             name  platform sub_platform  \
# 349951  jeremiahs italian ice (westside shoppes)  ubereats     ubereats
#
#         latitude  longitude country active
# 349951  28.45116 -81.562331      US    NaN

# %% [markdown]
# Because it's only one row of data, I'm simply going to look up this restaurant on the internet and label it by hand.
#
# This [restaurant](https://www.ubereats.com/orlando/food-delivery/jeremiahs-italian-ice-westside-shoppes/cK9rLjfWTs618-ydA1M7TA) is active on Ubereats, so I will change all NaN values in the dataset to be "TRUE" in the active column.

# %%
import numpy as np

# %%
# replacing all NaN in the active column with "TRUE"
data['active'] = data['active'].replace(np.NaN, 'TRUE')
data['active'].value_counts(dropna = False)
# Out:
# TRUE     568622
# FALSE     67450
# Name: active, dtype: int64

# %% [markdown]
# #### Exploring Sub-Platform Values

# %%
data['sub_platform'].value_counts(dropna = False)
# Out:
# doordash      349394
# restaurant    110237
# grubhub        68579
# ubereats       65740
# NaN            42122
# Name: sub_platform, dtype: int64

# %% [markdown]
# This column is an interesting column because if a restaurant only offers delivery via one platform, it makes perfect sense why the sub-platform column will have NaN values.
#
# At a glance, each data point at this stage of data cleaning has data for the 'platform' column. However, it is difficult to check or confirm whether each of the data points does or doesn't have a sub-platform.
#
# For deeper analyses, it might make sense to change NaN values to something like 'None', but for the scope of this assignment I do not intend to use this column any further for analyses and will leave the column as is. In fact, it might be useful to know which rows have a sub-platform depending on the type of analyses in the future, and therefore there is value in leaving in this column for possible transformations in the future.

# %% [markdown]
# <a id="cell4"></a>

# %% [markdown]
# ### The Solution: Creating My Target Column
#
# Back to [Top](#cell1)

# %% [markdown]
# #### My Answer for Duplicates

# %%
print('{} total restaurants were listed in the original/provided dataset.'.format(original_dataset.shape[0]))
print('{} total restaurants exist in the cleaned dataset.'.format(data.shape[0]))
# Out:
# 644089 total restaurants were listed in the original/provided dataset.
# 636072 total restaurants exist in the cleaned dataset.

# %%
data['duplicate'] = data.duplicated(subset = ['latitude','longitude'], keep = 'first') 

# keep = False labels everything that was duplicated as True (there's a duplicate of it in the data set)
# creating another column is possible with keep = first if you want to leave the first duplicate labeled as an original just for a simple aggregation

print(data['duplicate'].value_counts())

# The False indicates that it is NOT a duplicate. 
# Whatever value exists as "FALSE" above is what I can say are unique results 
# aggregated after data cleaning using coordinate data to filter our duplicates

print('\n')
print('{}% of the rows from the provided dataset contain unique restaurants.'.format(round(554095 / original_dataset.shape[0] * 100)))
# Out:
# False    554095
# True      81977
# Name: duplicate, dtype: int64
#
#
# 86% of the rows from the provided dataset contain unique restaurants.

# %% [markdown]
# There are 554,095 unique restaurants in this dataset (out of 636,072 restaurants in total).

# %% [markdown]
# #### Active vs. Inactive Restaurants

# %%
active_data = data[data['active'] == "TRUE"].copy()
inactive_data = data[data['active'] == "FALSE"].copy()

# %%
# resetting the duplicate labels for the split active/inactive data sets
active_data.drop(columns = ['duplicate'], inplace = True)
inactive_data.drop(columns = ['duplicate'], inplace = True)

active_data['duplicate'] = active_data.duplicated(subset = ['latitude','longitude'], keep = 'first') 
inactive_data['duplicate'] = inactive_data.duplicated(subset = ['latitude','longitude'], keep = 'first')

print('Active Dataset')
print(active_data['duplicate'].value_counts())
print('\n')
print('Inactive Dataset')
print(inactive_data['duplicate'].value_counts())
# Out:
# Active Dataset
# False    498453
# True      70169
# Name: duplicate, dtype: int64
#
#
# Inactive Dataset
# False    62824
# True      4626
# Name: duplicate, dtype: int64

# %%
new_dupes = (498453 + 62824)
print('After splitting the dataset into active and inactive restaurants, there are a total of {} original restaurants from both datasets.'.format(new_dupes))
# Out:
# After splitting the dataset into active and inactive restaurants, there are a total of 561277 original restaurants from both datasets.

# %% [markdown]
# This difference (561,277 vs. 554,095) can be explained. There are restaurants in the dataset that have inactive duplicates, and these were taken into account to get the final number of original restaurants.
#
# ___
#
# I will proceed with 554,095 being the final number of unique restaurants from the original dataset.
#
# For active restaurants, there are 498,453 unique restaurants.

# %% [markdown]
# #### Visualizing the Dataset

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from matplotlib.patches import ConnectionPatch

# %%
# pie graph of unique restaurants vs number of duplicate restaurants in the dataset
# data['duplicate'] = data.duplicated(subset = ['latitude','longitude'], keep = 'first') 
# print(data['duplicate'].value_counts())
fig1, ax1 = plt.subplots(figsize=(14,7))

fig1_labels = 'Unique Restaurants', 'Duplicate Restaurants'
ax1.pie([554095, 81977], 
        explode = (0, 0.1), 
        labels = fig1_labels, 
        autopct = '%1.1f%%', 
        shadow = False, 
        startangle = 180, 
        colors = ['gainsboro', 'gray'])
ax1.axis('equal')
ax1.set_title('The Dataset')

plt.show()
# fig1.savefig('fig1.png')

# %%
data['platform'].value_counts(normalize = True) * 100
# Out:
# doordash        54.929945
# postmates       17.330900
# grubhub         10.781641
# ubereats        10.335308
# delivery.com     5.134010
# caviar           1.488196
# Name: platform, dtype: float64

# %%
# bar of pie chart on exploded unique restaurant values

# make figure and assign axis objects
fig2 = plt.figure(figsize=(15, 9))
ax1 = fig2.add_subplot(121)
ax2 = fig2.add_subplot(122)
fig2.subplots_adjust(wspace=0)

# pie chart parameters
ratios = [554095, 81977]
labels = 'Unique Restaurants', 'Duplicates'
explode = [0.1, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * ratios[0]
ax1.pie(ratios, autopct = '%1.1f%%', startangle = angle, labels = labels, explode = explode, colors = ['gainsboro', 'gray'])

# bar chart parameters
xpos = 0
bottom = 0
ratios = [0.54929945, 0.17330900, 0.10781641, 0.10335308, 0.05134010, 0.01488196]
width = .2
colors = [[1, 0, 0], [0.1, 0.5, 0.5], [0.7, 0.3, 0], [0, 1, 0.4],[0, 0.5, 1], [1, 0.5, 0]]

for j in range(len(ratios)):
    height = ratios[j]
    ax2.bar(xpos, height, width, bottom=bottom, color=colors[j])
    ypos = bottom + ax2.patches[j].get_height() / 2
    bottom += height
    ax2.text(xpos, ypos, "%d%%" % (ax2.patches[j].get_height() * 100), ha='center')

ax2.set_title('Restaurant Delivery Platforms')
ax2.legend(('doordash', 'postmates', 'grubhub', 'ubereats', 'delivery.com', 'caviar'), loc = 'center right')
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots    # get the wedge data
theta1, theta2 = ax1.patches[0].theta1, ax1.patches[0].theta2
center, r = ax1.patches[0].center, ax1.patches[0].r
bar_height = sum([item.get_height() for item in ax2.patches])

# draw top connecting line
con = ConnectionPatch(xyA=(- width / 2, bar_height), xyB=(-0.1, 0.94),coordsA="data", coordsB="data", axesA=ax2, axesB=ax1)
con.set_color([0, 0, 0])
con.set_linewidth(2)
ax2.add_artist(con)

# draw bottom connecting line
con = ConnectionPatch(xyA=(- width / 2, 0), xyB=(-0.1, -1.015), coordsA="data",coordsB="data", axesA=ax2, axesB=ax1)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(2)

plt.show()
# fig2.savefig('fig2.png')

# %%
# count plot of unique restaurants vs number of duplicate restaurants in the dataset
fig3 = sns.countplot(x = 'duplicate', data = data, palette = 'Set2')
fig3.set_title('Unique vs. Duplicate Restaurants')
fig3

plt.show()
fig3 = fig3.get_figure()
# fig3.savefig('fig3.png')

# %%
# count plot of unique restaurants vs number of duplicate restaurants in the dataset for active restaurants only
fig4 = sns.countplot(x = 'duplicate', data = active_data, palette = 'Set2')
fig4.set_title('Unique vs. Duplicate Restaurants (Active Only)')
fig4

plt.show()
fig4 = fig4.get_figure()
# fig4.savefig('fig4.png')

# %%
### pie graph of frequencies of active vs inactive
fig5, ax1 = plt.subplots(figsize=(14,7))

fig5_labels = 'Active Restaurants', 'Inactive Restaurants'
ax1.pie([(data[data['active'] == 'TRUE'].shape[0]), (data[data['active'] == 'FALSE'].shape[0])], 
        explode = (0, 0.1), 
        labels = fig5_labels, 
        autopct = '%1.1f%%', 
        shadow = False, 
        startangle = 180, 
        colors = ['mediumseagreen', 'lightcoral'])
ax1.axis('equal')
ax1.set_title('The Dataset')

plt.show()
# fig5.savefig('fig5.png')

# %%
# count plot of active restaurants and the platforms they exist on
fig6 = sns.countplot(x = 'platform', data = active_data, palette = 'Set1')
fig6.set_title('Restaurant Platforms (Active Only)')
fig6

plt.show()
fig6 = fig6.get_figure()
# fig6.savefig('fig6.png')

# %%
# count plot of active restaurants and the platforms they exist on
fig7 = sns.countplot(x = 'platform', data = inactive_data, palette = 'Set1')
fig7.set_title('Restaurant Platforms (Inactive Only)')
fig7

plt.show()
fig7 = fig7.get_figure()
# fig7.savefig('fig7.png')

# %% [markdown]
# <a id="cell5"></a>

# %% [markdown]
# # Discussion: Potential Next Steps
#
# Back to [Top](#cell1)
#
# The majority of my week was spent on data hygiene. The most important aspect of working with data is making sure the data itself is of high quality.
#
# ## My Solution: 554,095 Unique Restaurants, 498,453 Unique & Active Restaurants
# I reached my solution for duplicates by creating a simple algorithm that matched duplicate entries by their latitude and longitude data. Latitude and longitude are very precise measurements of location, so it was a quick solution to identifying which rows of data were duplicates of an already existing restaurant.
# - I could not filter duplicates by platform as the same restaurant could be found on multiple platforms.
# - I could not filter duplicates by restaurant name as different restaurants could have the same name.
#
# ## The Value in the Data
# With some more work, the data could be even more valuable to decision-makers:
# - Knowing how many active/inactive restaurants are available on different delivery platforms can be helpful in developing various platform/product strategies
# - Filtering data by geographic location(s) can help decision-makers decide where (state, city) to invest in properties to maximize outcomes
# - On the [Cloud Kitchens website](https://www.cloudkitchens.com/), the platform assures users that "ghost kitchens come with all the pieces of the operations puzzle, so [restaurants] can focus on the food". A deeper dive into which types/categories/styles of restaurants may be more/less successful based on trends can allow the platform to fulfill its promises and be more beneficial to its users, ultimately leading to:
#     - increased user retention
#     - marketing via word-of-mouth
#     - more positive cross-functional outcomes
#
# ## What I Could Have Done (w/ More Time)
# After completing data cleaning, it may be possible to create machine learning algorithms to find duplicates. The problem with creating ML algorithms in this instance was time. I would have had to normalize columns of the data in much more complicated and time-consuming ways to create any sort of supervised or unsupervised model. Based on the columns I was given with the time-frame I had, I knew I didn't have enough time to engineer features in a manner that would lead to strong model results.
#
# One option I considered was using the [Dedupe Python library](https://github.com/dedupeio/dedupe). Dedupe is a python library that uses machine learning to perform fuzzy matching, deduplication and entity resolution quickly on structured data. However, I ruled this option out also. I did not feel that there was enough time to tune the model.
#
# ## Visualizations
# There are plenty of different types of visualizations I could have created. However, I kept my visualizations simple and only visualized my solution(s) and related metrics. Other possible visualizations could have included:
# - Active/Inactive restaurants map of the United States
# - Active/Inactive restaurants map by state
# - Mapping restaurants by delivery platform

# %% [markdown]
# #### An Example of the Capability of Mapping Geographically Using Basemap

# %%
from mpl_toolkits.basemap import Basemap

# %%
from itertools import chain

def draw_map(m, scale=0.2):
    # draw a shaded-relief image
    m.shadedrelief(scale=scale)
    
    # lats and longs are returned as a dictionary
    lats = m.drawparallels(np.linspace(-90, 90, 13))
    lons = m.drawmeridians(np.linspace(-180, 180, 13))

    # keys contain the plt.Line2D instances
    lat_lines = chain(*(tup[1][0] for tup in lats.items()))
    lon_lines = chain(*(tup[1][0] for tup in lons.items()))
    all_lines = chain(lat_lines, lon_lines)
    
    # cycle through these lines and set the desired style
    for line in all_lines:
        line.set(linestyle='-', alpha=0.3, color='w')
        
fig8 = plt.figure(figsize=(8, 6), edgecolor='w')
m = Basemap(projection='cyl', resolution=None,
            llcrnrlat=-90, urcrnrlat=90,
            llcrnrlon=-180, urcrnrlon=180, )
draw_map(m)

plt.show()
# fig8.savefig('fig8.png')

# %%
# basemap plot all coordinates of all unique restaurants
fig9 = plt.figure(figsize=(8, 6), edgecolor='black')
m = Basemap(projection='lcc', resolution=None,
            width=8E6, height=8E6, 
            lat_0=45, lon_0=-100,)

longitudes = data["longitude"].tolist()
latitudes = data["latitude"].tolist()
m.scatter(longitudes, latitudes, s=50, zorder=2, latlon=True, cmap="summer")

plt.show()
# fig9.savefig('fig9.png')

# %% [markdown]
# Back to [Top](#cell1)
